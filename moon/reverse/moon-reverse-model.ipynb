# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
import os
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

print("TensorFlow Version:", tf.__version__)
# Out:
# 2026-05-09 13:55:04.958207: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778334905.156807      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778334905.213078      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778334905.658875      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778334905.658914      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778334905.658917      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778334905.658920      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow Version: 2.19.0

# %%
def process_moon_reverse_data(file_path, num_points=100):
    if not os.path.exists(file_path): 
        raise FileNotFoundError(f'File not found: {file_path}')
        
    df = pd.read_csv(file_path, on_bad_lines='skip', skip_blank_lines=True)
    df.columns = df.columns.str.strip()
    df['Model_ID'] = pd.to_numeric(df['Model_ID'], errors='coerce')
    
    ids = df['Model_ID'].unique()
    
    # المدخلات الجديدة (الأداء)
    X_thrust, X_pressure, X_scalars = [], [], []
    # المخرجات الجديدة (الأبعاد الـ 6)
    Y_dimensions = []

    dim_cols = ['Length', 'Diameter', 'Core_Diameter', 'Core_Offset', 'Throat_Diameter', 'Exit_Diameter']

    for uid in ids:
        try:
            case_data = df[df['Model_ID'] == uid].sort_values('Time (s)')
            
            dims = case_data[dim_cols].iloc[0].values
            t = case_data['Time (s)'].values
            
            if len(t) < 2 or t[-1] <= 0 or np.any(dims <= 0): 
                continue

            thrust = case_data['Thrust (N)'].fillna(0).values
            pressure = case_data['Pressure (MPa)'].fillna(0).values

            if len(thrust) > 7:
                thrust = savgol_filter(thrust, window_length=7, polyorder=3)
                pressure = savgol_filter(pressure, window_length=7, polyorder=3)

            x_new = np.linspace(t[0], t[-1], num_points)
            
            X_thrust.append(interp1d(t, thrust, kind='linear', fill_value='extrapolate')(x_new))
            X_pressure.append(interp1d(t, pressure, kind='linear', fill_value='extrapolate')(x_new))
            
            X_scalars.append([
                case_data['ISP (s)'].iloc[0], 
                case_data['Total Impulse (Ns)'].iloc[0], 
                t[-1], 
                np.max(thrust)
            ])
            
            Y_dimensions.append(dims)
            
        except Exception: 
            continue
        
    return (np.array(X_thrust), np.array(X_pressure), np.array(X_scalars)), np.array(Y_dimensions)

# ==========================================
# ضع مسار ملف Moon Data هنا
file_path = '/kaggle/input/datasets/mahmoudabdelrazek11/new-moon/moon_grain_clean.csv' 
(Xt, Xp, Xs), Y_dims = process_moon_reverse_data(file_path) 

Xt, Xp, Xs = Xt.astype(float), Xp.astype(float), Xs.astype(float)
Y_dims = Y_dims.astype(float)

# توحيد الأطوال
min_s = min(len(Xt), len(Xp), len(Xs), len(Y_dims))
Xt, Xp, Xs, Y_dims = Xt[:min_s], Xp[:min_s], Xs[:min_s], Y_dims[:min_s]

print(f"✅ Moon Reverse Data loaded: {len(Y_dims)} cases.")
print(f"Target dimensions shape (Y): {Y_dims.shape}") # يجب أن يكون (N, 6)
# Out:
# ✅ Moon Reverse Data loaded: 4060 cases.
# Target dimensions shape (Y): (4060, 6)

# %%
# 1. تقسيم البيانات
Xt_tr, Xt_te, Xp_tr, Xp_te, Xs_tr, Xs_te, Y_tr, Y_te = train_test_split(
    Xt, Xp, Xs, Y_dims, test_size=0.15, random_state=42
)

# 2. التقييس الفيزيائي للمنحنيات (Global Max Scaling)
# هذا يحافظ على شكل المنحنى الفيزيائي 100% ويمنع الموديل من العمى
xt_max = np.max(Xt_tr)
xp_max = np.max(Xp_tr)

Xt_tr_s = Xt_tr / xt_max
Xt_te_s = Xt_te / xt_max

Xp_tr_s = Xp_tr / xp_max
Xp_te_s = Xp_te / xp_max

# 3. تقييس القيم الثابتة بـ MinMaxScaler
s_xs = MinMaxScaler()
Xs_tr_s = s_xs.fit_transform(Xs_tr)
Xs_te_s = s_xs.transform(Xs_te)

# 4. تقييس الأبعاد (المخرجات) بـ MinMaxScaler
s_Y = MinMaxScaler()
Y_tr_s = s_Y.fit_transform(Y_tr)
Y_te_s = s_Y.transform(Y_te)

# حفظ المقاييس الجديدة
joblib.dump({'xt_max': xt_max, 'xp_max': xp_max}, 'moon_rev_max_values.pkl')
joblib.dump(s_xs, 'moon_rev_scaler_scalars.pkl')
joblib.dump(s_Y, 'moon_rev_scaler_dims.pkl')

print("✅ Physical Scaling Applied Successfully!")
# Out:
# ✅ Physical Scaling Applied Successfully!

# %%
import tensorflow.keras.backend as K

def build_moon_reverse_model_v3():
    input_t = layers.Input(shape=(100,), name='Thrust_Profile_Input')
    input_p = layers.Input(shape=(100,), name='Pressure_Profile_Input')
    input_s = layers.Input(shape=(4,),   name='Scalars_Input')

    # استخراج الخصائص
    dense_t = layers.Dense(128, activation='elu')(input_t)
    dense_p = layers.Dense(128, activation='elu')(input_p)
    dense_s = layers.Dense(32,  activation='elu')(input_s)

    concat = layers.Concatenate()([dense_t, dense_p, dense_s])

    # شبكة عميقة 
    x = layers.Dense(256, activation='elu')(concat)
    x = layers.Dense(512, activation='elu')(x)
    x = layers.Dense(256, activation='elu')(x)

    # المخرجات الـ 6
    output_dims = layers.Dense(6, activation='linear', name='Dimensions_Output')(x)

    model = Model(inputs=[input_t, input_p, input_s], outputs=output_dims)
    
    # ==========================================
    # 🎯 Custom Physics-Weighted Loss
    # الترتيب: [Length, Diameter, Core_Dia, Core_Offset, Throat_Dia, Exit_Dia]
    # نعطي وزن 4 للقطر و 2 للطول و 2 للفوهة، لنجبره على ضبط الهيكل الخارجي أولاً
    # ==========================================
    def weighted_mse(y_true, y_pred):
        weights = tf.constant([2.0, 4.0, 1.0, 1.0, 2.0, 1.0], dtype=tf.float32)
        return K.mean(weights * K.square(y_true - y_pred), axis=-1)

    # استخدام الدالة المخصصة
    model.compile(optimizer=Adam(learning_rate=0.001), loss=weighted_mse)
    
    return model

moon_reverse = build_moon_reverse_model_v3()
moon_reverse.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Thrust_Profile_Inp… │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Pressure_Profile_I… │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Scalars_Input       │ (None, 4)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 128)       │     12,928 │ Thrust_Profile_I… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 128)       │     12,928 │ Pressure_Profile… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 32)        │        160 │ Scalars_Input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 288)       │          0 │ dense_22[0][0],   │
# │ (Concatenate)       │                   │            │ dense_23[0][0],   │
# │                     │                   │            │ dense_24[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 256)       │     73,984 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 512)       │    131,584 │ dense_25[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 256)       │    131,328 │ dense_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Dimensions_Output   │ (None, 6)         │      1,542 │ dense_27[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 364,454 (1.39 MB)
#  Trainable params: 364,454 (1.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-5, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

print("Starting training for Moon Reverse Model...")
history_rev = moon_reverse.fit(
    x=[Xt_tr_s, Xp_tr_s, Xs_tr_s], 
    y=Y_tr_s,
    validation_split=0.15,
    epochs=400,
    batch_size=32,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)

# حفظ الموديل العكسي
moon_reverse.save('Moon_Reverse_Model.keras')
print("\n✅ Moon Reverse Model trained and saved successfully.")
# Out:
# Starting training for Moon Reverse Model...
# Epoch 1/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1106 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 2/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0252 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 3/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - val_loss: 0.0198 - learning_rate: 0.0010
# Epoch 4/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0190 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 5/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0204 - val_loss: 0.0178 - learning_rate: 0.0010
# Epoch 6/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - val_loss: 0.0170 - learning_rate: 0.0010
# Epoch 7/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0149 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 8/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 9/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0138 - val_loss: 0.0124 - learning_rate: 0.0010
# Epoch 10/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124 - val_loss: 0.0145 - learning_rate: 0.0010
# Epoch 11/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 12/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0113 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 13/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - val_loss: 0.0107 - learning_rate: 0.0010
# Epoch 14/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0110 - val_loss: 0.0123 - learning_rate: 0.0010
# Epoch 15/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 16/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 17/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 18/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 19/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 20/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 21/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 22/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 23/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 24/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 25/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 26/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 27/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 28/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 29/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 30/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 31/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 32/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - val_loss: 0.0060 - learning_rate: 0.0010
# Epoch 33/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 34/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 35/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 36/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 37/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 38/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 39/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 40/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 41/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 42/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 43/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 44/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - val_loss: 0.0040 - learning_rate: 0.0010
# Epoch 45/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 46/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 47/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 48/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 49/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 50/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 51/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 52/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 53/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 54/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 55/400
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 56/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 57/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 58/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 59/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 60/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 61/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0018 - learning_rate: 5.0000e-04
# Epoch 62/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0019 - learning_rate: 5.0000e-04
# Epoch 63/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 64/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 65/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 66/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0019 - learning_rate: 5.0000e-04
# Epoch 67/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 68/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 69/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 70/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0019 - learning_rate: 5.0000e-04
# Epoch 71/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 72/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 73/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 74/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 75/400
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 76/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - val_loss: 8.4936e-04 - learning_rate: 2.5000e-04
# Epoch 77/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4770e-04 - val_loss: 0.0011 - learning_rate: 2.5000e-04
# Epoch 78/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5497e-04 - val_loss: 9.7923e-04 - learning_rate: 2.5000e-04
# Epoch 79/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5868e-04 - val_loss: 9.5665e-04 - learning_rate: 2.5000e-04
# Epoch 80/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3350e-04 - val_loss: 8.2435e-04 - learning_rate: 2.5000e-04
# Epoch 81/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9414e-04 - val_loss: 8.0890e-04 - learning_rate: 2.5000e-04
# Epoch 82/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4863e-04 - val_loss: 8.6939e-04 - learning_rate: 2.5000e-04
# Epoch 83/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - val_loss: 8.6862e-04 - learning_rate: 2.5000e-04
# Epoch 84/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5732e-04 - val_loss: 8.4659e-04 - learning_rate: 2.5000e-04
# Epoch 85/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5355e-04 - val_loss: 0.0011 - learning_rate: 2.5000e-04
# Epoch 86/400
# 70/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6361e-04
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5145e-04 - val_loss: 8.1744e-04 - learning_rate: 2.5000e-04
# Epoch 87/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3076e-04 - val_loss: 6.7527e-04 - learning_rate: 1.2500e-04
# Epoch 88/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7373e-04 - val_loss: 8.0728e-04 - learning_rate: 1.2500e-04
# Epoch 89/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2852e-04 - val_loss: 8.0668e-04 - learning_rate: 1.2500e-04
# Epoch 90/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2661e-04 - val_loss: 7.7980e-04 - learning_rate: 1.2500e-04
# Epoch 91/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0411e-04 - val_loss: 7.8624e-04 - learning_rate: 1.2500e-04
# Epoch 92/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7158e-04 - val_loss: 6.5894e-04 - learning_rate: 1.2500e-04
# Epoch 93/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8516e-04 - val_loss: 6.7867e-04 - learning_rate: 1.2500e-04
# Epoch 94/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3841e-04 - val_loss: 7.8771e-04 - learning_rate: 1.2500e-04
# Epoch 95/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0850e-04 - val_loss: 6.4197e-04 - learning_rate: 1.2500e-04
# Epoch 96/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4568e-04 - val_loss: 7.0511e-04 - learning_rate: 1.2500e-04
# Epoch 97/400
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7085e-04
# Epoch 97: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7125e-04 - val_loss: 7.6936e-04 - learning_rate: 1.2500e-04
# Epoch 98/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1394e-04 - val_loss: 6.1956e-04 - learning_rate: 6.2500e-05
# Epoch 99/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7866e-04 - val_loss: 6.1124e-04 - learning_rate: 6.2500e-05
# Epoch 100/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8418e-04 - val_loss: 5.8908e-04 - learning_rate: 6.2500e-05
# Epoch 101/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9287e-04 - val_loss: 5.8219e-04 - learning_rate: 6.2500e-05
# Epoch 102/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5070e-04 - val_loss: 6.6034e-04 - learning_rate: 6.2500e-05
# Epoch 103/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8556e-04 - val_loss: 6.5067e-04 - learning_rate: 6.2500e-05
# Epoch 104/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0268e-04 - val_loss: 6.8716e-04 - learning_rate: 6.2500e-05
# Epoch 105/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7304e-04 - val_loss: 6.3624e-04 - learning_rate: 6.2500e-05
# Epoch 106/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6565e-04 - val_loss: 7.1460e-04 - learning_rate: 6.2500e-05
# Epoch 107/400
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6130e-04
# Epoch 107: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6098e-04 - val_loss: 5.7915e-04 - learning_rate: 6.2500e-05
# Epoch 108/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0272e-04 - val_loss: 5.9410e-04 - learning_rate: 3.1250e-05
# Epoch 109/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6322e-04 - val_loss: 5.5335e-04 - learning_rate: 3.1250e-05
# Epoch 110/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0457e-04 - val_loss: 5.5170e-04 - learning_rate: 3.1250e-05
# Epoch 111/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1434e-04 - val_loss: 5.6786e-04 - learning_rate: 3.1250e-05
# Epoch 112/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1728e-04 - val_loss: 5.5809e-04 - learning_rate: 3.1250e-05
# Epoch 113/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9034e-04 - val_loss: 5.6074e-04 - learning_rate: 3.1250e-05
# Epoch 114/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3335e-04 - val_loss: 5.7330e-04 - learning_rate: 3.1250e-05
# Epoch 115/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7600e-04 - val_loss: 5.3727e-04 - learning_rate: 3.1250e-05
# Epoch 116/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6914e-04 - val_loss: 5.7339e-04 - learning_rate: 3.1250e-05
# Epoch 117/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0155e-04 - val_loss: 5.6130e-04 - learning_rate: 3.1250e-05
# Epoch 118/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0926e-04 - val_loss: 5.5530e-04 - learning_rate: 3.1250e-05
# Epoch 119/400
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0621e-04
# Epoch 119: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0577e-04 - val_loss: 5.4711e-04 - learning_rate: 3.1250e-05
# Epoch 120/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3387e-04 - val_loss: 5.2660e-04 - learning_rate: 1.5625e-05
# Epoch 121/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7385e-04 - val_loss: 5.5736e-04 - learning_rate: 1.5625e-05
# Epoch 122/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1452e-04 - val_loss: 5.3007e-04 - learning_rate: 1.5625e-05
# Epoch 123/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6534e-04 - val_loss: 5.2936e-04 - learning_rate: 1.5625e-05
# Epoch 124/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7319e-04 - val_loss: 5.2763e-04 - learning_rate: 1.5625e-05
# Epoch 125/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7769e-04 - val_loss: 5.5249e-04 - learning_rate: 1.5625e-05
# Epoch 126/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7387e-04 - val_loss: 5.4242e-04 - learning_rate: 1.5625e-05
# Epoch 127/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9238e-04 - val_loss: 5.1902e-04 - learning_rate: 1.5625e-05
# Epoch 128/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5988e-04 - val_loss: 5.6398e-04 - learning_rate: 1.5625e-05
# Epoch 129/400
# 85/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5421e-04
# Epoch 129: ReduceLROnPlateau reducing learning rate to 1e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5586e-04 - val_loss: 5.3204e-04 - learning_rate: 1.5625e-05
# Epoch 130/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6960e-04 - val_loss: 5.2260e-04 - learning_rate: 1.0000e-05
# Epoch 131/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7922e-04 - val_loss: 5.2439e-04 - learning_rate: 1.0000e-05
# Epoch 132/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7392e-04 - val_loss: 5.1026e-04 - learning_rate: 1.0000e-05
# Epoch 133/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2551e-04 - val_loss: 5.4267e-04 - learning_rate: 1.0000e-05
# Epoch 134/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4408e-04 - val_loss: 5.1615e-04 - learning_rate: 1.0000e-05
# Epoch 135/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4676e-04 - val_loss: 5.2384e-04 - learning_rate: 1.0000e-05
# Epoch 136/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6504e-04 - val_loss: 5.3954e-04 - learning_rate: 1.0000e-05
# Epoch 137/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7436e-04 - val_loss: 5.1982e-04 - learning_rate: 1.0000e-05
# Epoch 138/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4785e-04 - val_loss: 5.3454e-04 - learning_rate: 1.0000e-05
# Epoch 139/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7425e-04 - val_loss: 5.2510e-04 - learning_rate: 1.0000e-05
# Epoch 140/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5516e-04 - val_loss: 5.4384e-04 - learning_rate: 1.0000e-05
# Epoch 141/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7962e-04 - val_loss: 5.1106e-04 - learning_rate: 1.0000e-05
# Epoch 142/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5117e-04 - val_loss: 5.0698e-04 - learning_rate: 1.0000e-05
# Epoch 143/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7007e-04 - val_loss: 5.1950e-04 - learning_rate: 1.0000e-05
# Epoch 144/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3407e-04 - val_loss: 5.0440e-04 - learning_rate: 1.0000e-05
# Epoch 145/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4971e-04 - val_loss: 5.1621e-04 - learning_rate: 1.0000e-05
# Epoch 146/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4478e-04 - val_loss: 5.0797e-04 - learning_rate: 1.0000e-05
# Epoch 147/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3916e-04 - val_loss: 5.1122e-04 - learning_rate: 1.0000e-05
# Epoch 148/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4700e-04 - val_loss: 5.3115e-04 - learning_rate: 1.0000e-05
# Epoch 149/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7274e-04 - val_loss: 5.3739e-04 - learning_rate: 1.0000e-05
# Epoch 150/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3937e-04 - val_loss: 5.3164e-04 - learning_rate: 1.0000e-05
# Epoch 151/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2379e-04 - val_loss: 5.3922e-04 - learning_rate: 1.0000e-05
# Epoch 152/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5386e-04 - val_loss: 5.0731e-04 - learning_rate: 1.0000e-05
# Epoch 153/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2916e-04 - val_loss: 5.1427e-04 - learning_rate: 1.0000e-05
# Epoch 154/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3209e-04 - val_loss: 4.9681e-04 - learning_rate: 1.0000e-05
# Epoch 155/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7444e-04 - val_loss: 5.1433e-04 - learning_rate: 1.0000e-05
# Epoch 156/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3636e-04 - val_loss: 4.9710e-04 - learning_rate: 1.0000e-05
# Epoch 157/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9691e-04 - val_loss: 5.0881e-04 - learning_rate: 1.0000e-05
# Epoch 158/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5904e-04 - val_loss: 5.0683e-04 - learning_rate: 1.0000e-05
# Epoch 159/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3373e-04 - val_loss: 4.9349e-04 - learning_rate: 1.0000e-05
# Epoch 160/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4994e-04 - val_loss: 4.9823e-04 - learning_rate: 1.0000e-05
# Epoch 161/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2372e-04 - val_loss: 4.9459e-04 - learning_rate: 1.0000e-05
# Epoch 162/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5873e-04 - val_loss: 5.2136e-04 - learning_rate: 1.0000e-05
# Epoch 163/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5787e-04 - val_loss: 4.9436e-04 - learning_rate: 1.0000e-05
# Epoch 164/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1717e-04 - val_loss: 5.0107e-04 - learning_rate: 1.0000e-05
# Epoch 165/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6832e-04 - val_loss: 5.0102e-04 - learning_rate: 1.0000e-05
# Epoch 166/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7426e-04 - val_loss: 5.2359e-04 - learning_rate: 1.0000e-05
# Epoch 167/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3343e-04 - val_loss: 5.1320e-04 - learning_rate: 1.0000e-05
# Epoch 168/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1776e-04 - val_loss: 5.1229e-04 - learning_rate: 1.0000e-05
# Epoch 169/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7702e-04 - val_loss: 5.0484e-04 - learning_rate: 1.0000e-05
# Epoch 170/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0233e-04 - val_loss: 4.9646e-04 - learning_rate: 1.0000e-05
# Epoch 171/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8264e-04 - val_loss: 4.9286e-04 - learning_rate: 1.0000e-05
# Epoch 172/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2925e-04 - val_loss: 4.9409e-04 - learning_rate: 1.0000e-05
# Epoch 173/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1799e-04 - val_loss: 5.0856e-04 - learning_rate: 1.0000e-05
# Epoch 174/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3093e-04 - val_loss: 5.0490e-04 - learning_rate: 1.0000e-05
# Epoch 175/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2331e-04 - val_loss: 5.0269e-04 - learning_rate: 1.0000e-05
# Epoch 176/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4932e-04 - val_loss: 5.3025e-04 - learning_rate: 1.0000e-05
# Epoch 177/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9344e-04 - val_loss: 4.9774e-04 - learning_rate: 1.0000e-05
# Epoch 178/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2503e-04 - val_loss: 4.9530e-04 - learning_rate: 1.0000e-05
# Epoch 179/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5380e-04 - val_loss: 5.0653e-04 - learning_rate: 1.0000e-05
# Epoch 180/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2365e-04 - val_loss: 4.8281e-04 - learning_rate: 1.0000e-05
# Epoch 181/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1018e-04 - val_loss: 4.8245e-04 - learning_rate: 1.0000e-05
# Epoch 182/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1466e-04 - val_loss: 5.1554e-04 - learning_rate: 1.0000e-05
# Epoch 183/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3329e-04 - val_loss: 4.8326e-04 - learning_rate: 1.0000e-05
# Epoch 184/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2542e-04 - val_loss: 4.8886e-04 - learning_rate: 1.0000e-05
# Epoch 185/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4642e-04 - val_loss: 4.8039e-04 - learning_rate: 1.0000e-05
# Epoch 186/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1187e-04 - val_loss: 4.9762e-04 - learning_rate: 1.0000e-05
# Epoch 187/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2352e-04 - val_loss: 5.0821e-04 - learning_rate: 1.0000e-05
# Epoch 188/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5223e-04 - val_loss: 5.1529e-04 - learning_rate: 1.0000e-05
# Epoch 189/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0840e-04 - val_loss: 4.9096e-04 - learning_rate: 1.0000e-05
# Epoch 190/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1646e-04 - val_loss: 5.3423e-04 - learning_rate: 1.0000e-05
# Epoch 191/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3220e-04 - val_loss: 4.8381e-04 - learning_rate: 1.0000e-05
# Epoch 192/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2180e-04 - val_loss: 4.8258e-04 - learning_rate: 1.0000e-05
# Epoch 193/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3204e-04 - val_loss: 4.8928e-04 - learning_rate: 1.0000e-05
# Epoch 194/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0440e-04 - val_loss: 4.9827e-04 - learning_rate: 1.0000e-05
# Epoch 195/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3722e-04 - val_loss: 5.2507e-04 - learning_rate: 1.0000e-05
# Epoch 196/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1708e-04 - val_loss: 4.8174e-04 - learning_rate: 1.0000e-05
# Epoch 197/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1534e-04 - val_loss: 4.9694e-04 - learning_rate: 1.0000e-05
# Epoch 198/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3401e-04 - val_loss: 4.8497e-04 - learning_rate: 1.0000e-05
# Epoch 199/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0616e-04 - val_loss: 4.8659e-04 - learning_rate: 1.0000e-05
# Epoch 200/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8377e-04 - val_loss: 4.7596e-04 - learning_rate: 1.0000e-05
# Epoch 201/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3767e-04 - val_loss: 4.8636e-04 - learning_rate: 1.0000e-05
# Epoch 202/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2969e-04 - val_loss: 4.7819e-04 - learning_rate: 1.0000e-05
# Epoch 203/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4164e-04 - val_loss: 4.9919e-04 - learning_rate: 1.0000e-05
# Epoch 204/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5611e-04 - val_loss: 4.7613e-04 - learning_rate: 1.0000e-05
# Epoch 205/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2793e-04 - val_loss: 4.7439e-04 - learning_rate: 1.0000e-05
# Epoch 206/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0484e-04 - val_loss: 4.9430e-04 - learning_rate: 1.0000e-05
# Epoch 207/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2212e-04 - val_loss: 5.0238e-04 - learning_rate: 1.0000e-05
# Epoch 208/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0629e-04 - val_loss: 4.7695e-04 - learning_rate: 1.0000e-05
# Epoch 209/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0126e-04 - val_loss: 4.8726e-04 - learning_rate: 1.0000e-05
# Epoch 210/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1949e-04 - val_loss: 4.7101e-04 - learning_rate: 1.0000e-05
# Epoch 211/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1419e-04 - val_loss: 4.8026e-04 - learning_rate: 1.0000e-05
# Epoch 212/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1511e-04 - val_loss: 4.9234e-04 - learning_rate: 1.0000e-05
# Epoch 213/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3597e-04 - val_loss: 5.0913e-04 - learning_rate: 1.0000e-05
# Epoch 214/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3267e-04 - val_loss: 4.9128e-04 - learning_rate: 1.0000e-05
# Epoch 215/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1349e-04 - val_loss: 4.8120e-04 - learning_rate: 1.0000e-05
# Epoch 216/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8701e-04 - val_loss: 4.7449e-04 - learning_rate: 1.0000e-05
# Epoch 217/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1331e-04 - val_loss: 4.7259e-04 - learning_rate: 1.0000e-05
# Epoch 218/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2861e-04 - val_loss: 4.6771e-04 - learning_rate: 1.0000e-05
# Epoch 219/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2254e-04 - val_loss: 4.7063e-04 - learning_rate: 1.0000e-05
# Epoch 220/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1817e-04 - val_loss: 4.6693e-04 - learning_rate: 1.0000e-05
# Epoch 221/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9360e-04 - val_loss: 4.6823e-04 - learning_rate: 1.0000e-05
# Epoch 222/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2401e-04 - val_loss: 4.8580e-04 - learning_rate: 1.0000e-05
# Epoch 223/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2538e-04 - val_loss: 4.7235e-04 - learning_rate: 1.0000e-05
# Epoch 224/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1283e-04 - val_loss: 4.9900e-04 - learning_rate: 1.0000e-05
# Epoch 225/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7761e-04 - val_loss: 4.8480e-04 - learning_rate: 1.0000e-05
# Epoch 226/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4215e-04 - val_loss: 4.8971e-04 - learning_rate: 1.0000e-05
# Epoch 227/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0296e-04 - val_loss: 4.6644e-04 - learning_rate: 1.0000e-05
# Epoch 228/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1622e-04 - val_loss: 4.6784e-04 - learning_rate: 1.0000e-05
# Epoch 229/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8885e-04 - val_loss: 4.8098e-04 - learning_rate: 1.0000e-05
# Epoch 230/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8967e-04 - val_loss: 4.9600e-04 - learning_rate: 1.0000e-05
# Epoch 231/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1341e-04 - val_loss: 4.8068e-04 - learning_rate: 1.0000e-05
# Epoch 232/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2977e-04 - val_loss: 4.5284e-04 - learning_rate: 1.0000e-05
# Epoch 233/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3946e-04 - val_loss: 4.7300e-04 - learning_rate: 1.0000e-05
# Epoch 234/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8667e-04 - val_loss: 4.7389e-04 - learning_rate: 1.0000e-05
# Epoch 235/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0141e-04 - val_loss: 4.6760e-04 - learning_rate: 1.0000e-05
# Epoch 236/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0066e-04 - val_loss: 4.5655e-04 - learning_rate: 1.0000e-05
# Epoch 237/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4023e-04 - val_loss: 4.9813e-04 - learning_rate: 1.0000e-05
# Epoch 238/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3337e-04 - val_loss: 4.6612e-04 - learning_rate: 1.0000e-05
# Epoch 239/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0285e-04 - val_loss: 4.8228e-04 - learning_rate: 1.0000e-05
# Epoch 240/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8283e-04 - val_loss: 4.8023e-04 - learning_rate: 1.0000e-05
# Epoch 241/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8616e-04 - val_loss: 4.6560e-04 - learning_rate: 1.0000e-05
# Epoch 242/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0103e-04 - val_loss: 4.5713e-04 - learning_rate: 1.0000e-05
# Epoch 243/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2288e-04 - val_loss: 4.5867e-04 - learning_rate: 1.0000e-05
# Epoch 244/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2273e-04 - val_loss: 4.6379e-04 - learning_rate: 1.0000e-05
# Epoch 245/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0084e-04 - val_loss: 4.5966e-04 - learning_rate: 1.0000e-05
# Epoch 246/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9372e-04 - val_loss: 5.0220e-04 - learning_rate: 1.0000e-05
# Epoch 247/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7968e-04 - val_loss: 4.8427e-04 - learning_rate: 1.0000e-05
# Epoch 248/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9575e-04 - val_loss: 4.6145e-04 - learning_rate: 1.0000e-05
# Epoch 249/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1420e-04 - val_loss: 4.5872e-04 - learning_rate: 1.0000e-05
# Epoch 250/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7784e-04 - val_loss: 4.8300e-04 - learning_rate: 1.0000e-05
# Epoch 251/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1728e-04 - val_loss: 4.6480e-04 - learning_rate: 1.0000e-05
# Epoch 252/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2904e-04 - val_loss: 4.9300e-04 - learning_rate: 1.0000e-05
# Epoch 253/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0203e-04 - val_loss: 4.7482e-04 - learning_rate: 1.0000e-05
# Epoch 254/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0994e-04 - val_loss: 4.5508e-04 - learning_rate: 1.0000e-05
# Epoch 255/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7977e-04 - val_loss: 4.6621e-04 - learning_rate: 1.0000e-05
# Epoch 256/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8013e-04 - val_loss: 4.5882e-04 - learning_rate: 1.0000e-05
# Epoch 257/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9589e-04 - val_loss: 4.8660e-04 - learning_rate: 1.0000e-05
# Epoch 258/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6905e-04 - val_loss: 4.7286e-04 - learning_rate: 1.0000e-05
# Epoch 259/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2821e-04 - val_loss: 4.5780e-04 - learning_rate: 1.0000e-05
# Epoch 260/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1686e-04 - val_loss: 4.6765e-04 - learning_rate: 1.0000e-05
# Epoch 261/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9289e-04 - val_loss: 4.7985e-04 - learning_rate: 1.0000e-05
# Epoch 262/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1346e-04 - val_loss: 4.7108e-04 - learning_rate: 1.0000e-05
# Epoch 263/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6938e-04 - val_loss: 4.5273e-04 - learning_rate: 1.0000e-05
# Epoch 264/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7984e-04 - val_loss: 4.4963e-04 - learning_rate: 1.0000e-05
# Epoch 265/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6640e-04 - val_loss: 4.6060e-04 - learning_rate: 1.0000e-05
# Epoch 266/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8276e-04 - val_loss: 4.8276e-04 - learning_rate: 1.0000e-05
# Epoch 267/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1473e-04 - val_loss: 4.8957e-04 - learning_rate: 1.0000e-05
# Epoch 268/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9449e-04 - val_loss: 4.5892e-04 - learning_rate: 1.0000e-05
# Epoch 269/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8204e-04 - val_loss: 4.4684e-04 - learning_rate: 1.0000e-05
# Epoch 270/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6603e-04 - val_loss: 4.5307e-04 - learning_rate: 1.0000e-05
# Epoch 271/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9297e-04 - val_loss: 4.5124e-04 - learning_rate: 1.0000e-05
# Epoch 272/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8955e-04 - val_loss: 4.7208e-04 - learning_rate: 1.0000e-05
# Epoch 273/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8118e-04 - val_loss: 4.4735e-04 - learning_rate: 1.0000e-05
# Epoch 274/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7436e-04 - val_loss: 4.6508e-04 - learning_rate: 1.0000e-05
# Epoch 275/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2805e-04 - val_loss: 4.3935e-04 - learning_rate: 1.0000e-05
# Epoch 276/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8302e-04 - val_loss: 4.7421e-04 - learning_rate: 1.0000e-05
# Epoch 277/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9593e-04 - val_loss: 4.6715e-04 - learning_rate: 1.0000e-05
# Epoch 278/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1396e-04 - val_loss: 4.7566e-04 - learning_rate: 1.0000e-05
# Epoch 279/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7634e-04 - val_loss: 4.4505e-04 - learning_rate: 1.0000e-05
# Epoch 280/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8812e-04 - val_loss: 4.5172e-04 - learning_rate: 1.0000e-05
# Epoch 281/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6736e-04 - val_loss: 4.4091e-04 - learning_rate: 1.0000e-05
# Epoch 282/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4566e-04 - val_loss: 4.4013e-04 - learning_rate: 1.0000e-05
# Epoch 283/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7356e-04 - val_loss: 4.4336e-04 - learning_rate: 1.0000e-05
# Epoch 284/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7338e-04 - val_loss: 4.3708e-04 - learning_rate: 1.0000e-05
# Epoch 285/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7687e-04 - val_loss: 4.4298e-04 - learning_rate: 1.0000e-05
# Epoch 286/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0815e-04 - val_loss: 4.4952e-04 - learning_rate: 1.0000e-05
# Epoch 287/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1281e-04 - val_loss: 4.6601e-04 - learning_rate: 1.0000e-05
# Epoch 288/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8125e-04 - val_loss: 4.6823e-04 - learning_rate: 1.0000e-05
# Epoch 289/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8489e-04 - val_loss: 4.3779e-04 - learning_rate: 1.0000e-05
# Epoch 290/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3157e-04 - val_loss: 4.4490e-04 - learning_rate: 1.0000e-05
# Epoch 291/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8531e-04 - val_loss: 4.3400e-04 - learning_rate: 1.0000e-05
# Epoch 292/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0897e-04 - val_loss: 4.4357e-04 - learning_rate: 1.0000e-05
# Epoch 293/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6736e-04 - val_loss: 4.3789e-04 - learning_rate: 1.0000e-05
# Epoch 294/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7882e-04 - val_loss: 4.2892e-04 - learning_rate: 1.0000e-05
# Epoch 295/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8233e-04 - val_loss: 4.3745e-04 - learning_rate: 1.0000e-05
# Epoch 296/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9363e-04 - val_loss: 4.3861e-04 - learning_rate: 1.0000e-05
# Epoch 297/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8363e-04 - val_loss: 4.4373e-04 - learning_rate: 1.0000e-05
# Epoch 298/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6366e-04 - val_loss: 4.5029e-04 - learning_rate: 1.0000e-05
# Epoch 299/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9493e-04 - val_loss: 4.2833e-04 - learning_rate: 1.0000e-05
# Epoch 300/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8012e-04 - val_loss: 4.3957e-04 - learning_rate: 1.0000e-05
# Epoch 301/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9482e-04 - val_loss: 4.6143e-04 - learning_rate: 1.0000e-05
# Epoch 302/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7410e-04 - val_loss: 4.3371e-04 - learning_rate: 1.0000e-05
# Epoch 303/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0989e-04 - val_loss: 4.3326e-04 - learning_rate: 1.0000e-05
# Epoch 304/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1146e-04 - val_loss: 4.7144e-04 - learning_rate: 1.0000e-05
# Epoch 305/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7521e-04 - val_loss: 4.4427e-04 - learning_rate: 1.0000e-05
# Epoch 306/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5672e-04 - val_loss: 4.5194e-04 - learning_rate: 1.0000e-05
# Epoch 307/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7856e-04 - val_loss: 4.2529e-04 - learning_rate: 1.0000e-05
# Epoch 308/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6619e-04 - val_loss: 4.5066e-04 - learning_rate: 1.0000e-05
# Epoch 309/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6179e-04 - val_loss: 4.3641e-04 - learning_rate: 1.0000e-05
# Epoch 310/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7872e-04 - val_loss: 4.4468e-04 - learning_rate: 1.0000e-05
# Epoch 311/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7267e-04 - val_loss: 4.2205e-04 - learning_rate: 1.0000e-05
# Epoch 312/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2446e-04 - val_loss: 4.2192e-04 - learning_rate: 1.0000e-05
# Epoch 313/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5170e-04 - val_loss: 4.2494e-04 - learning_rate: 1.0000e-05
# Epoch 314/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6052e-04 - val_loss: 4.2546e-04 - learning_rate: 1.0000e-05
# Epoch 315/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5922e-04 - val_loss: 4.2930e-04 - learning_rate: 1.0000e-05
# Epoch 316/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4951e-04 - val_loss: 4.3130e-04 - learning_rate: 1.0000e-05
# Epoch 317/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8867e-04 - val_loss: 4.5046e-04 - learning_rate: 1.0000e-05
# Epoch 318/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8455e-04 - val_loss: 4.1388e-04 - learning_rate: 1.0000e-05
# Epoch 319/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0091e-04 - val_loss: 4.4201e-04 - learning_rate: 1.0000e-05
# Epoch 320/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8578e-04 - val_loss: 4.5454e-04 - learning_rate: 1.0000e-05
# Epoch 321/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0282e-04 - val_loss: 4.2571e-04 - learning_rate: 1.0000e-05
# Epoch 322/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6547e-04 - val_loss: 4.4854e-04 - learning_rate: 1.0000e-05
# Epoch 323/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4615e-04 - val_loss: 4.3630e-04 - learning_rate: 1.0000e-05
# Epoch 324/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7179e-04 - val_loss: 4.4092e-04 - learning_rate: 1.0000e-05
# Epoch 325/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5908e-04 - val_loss: 4.4103e-04 - learning_rate: 1.0000e-05
# Epoch 326/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8170e-04 - val_loss: 4.2997e-04 - learning_rate: 1.0000e-05
# Epoch 327/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6313e-04 - val_loss: 4.1940e-04 - learning_rate: 1.0000e-05
# Epoch 328/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6304e-04 - val_loss: 4.3296e-04 - learning_rate: 1.0000e-05
# Epoch 329/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6760e-04 - val_loss: 4.2908e-04 - learning_rate: 1.0000e-05
# Epoch 330/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9062e-04 - val_loss: 4.5606e-04 - learning_rate: 1.0000e-05
# Epoch 331/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9184e-04 - val_loss: 4.3275e-04 - learning_rate: 1.0000e-05
# Epoch 332/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5009e-04 - val_loss: 4.1064e-04 - learning_rate: 1.0000e-05
# Epoch 333/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3771e-04 - val_loss: 4.1552e-04 - learning_rate: 1.0000e-05
# Epoch 334/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5789e-04 - val_loss: 4.6439e-04 - learning_rate: 1.0000e-05
# Epoch 335/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6551e-04 - val_loss: 4.3673e-04 - learning_rate: 1.0000e-05
# Epoch 336/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4202e-04 - val_loss: 4.1935e-04 - learning_rate: 1.0000e-05
# Epoch 337/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3926e-04 - val_loss: 4.2129e-04 - learning_rate: 1.0000e-05
# Epoch 338/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5495e-04 - val_loss: 4.1975e-04 - learning_rate: 1.0000e-05
# Epoch 339/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2943e-04 - val_loss: 4.2640e-04 - learning_rate: 1.0000e-05
# Epoch 340/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4901e-04 - val_loss: 4.3296e-04 - learning_rate: 1.0000e-05
# Epoch 341/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5350e-04 - val_loss: 4.3503e-04 - learning_rate: 1.0000e-05
# Epoch 342/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6089e-04 - val_loss: 4.2277e-04 - learning_rate: 1.0000e-05
# Epoch 343/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7198e-04 - val_loss: 4.2200e-04 - learning_rate: 1.0000e-05
# Epoch 344/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3881e-04 - val_loss: 4.0914e-04 - learning_rate: 1.0000e-05
# Epoch 345/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4650e-04 - val_loss: 4.2173e-04 - learning_rate: 1.0000e-05
# Epoch 346/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7285e-04 - val_loss: 4.1918e-04 - learning_rate: 1.0000e-05
# Epoch 347/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6688e-04 - val_loss: 4.1252e-04 - learning_rate: 1.0000e-05
# Epoch 348/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4525e-04 - val_loss: 4.0800e-04 - learning_rate: 1.0000e-05
# Epoch 349/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3590e-04 - val_loss: 4.1967e-04 - learning_rate: 1.0000e-05
# Epoch 350/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4632e-04 - val_loss: 4.2866e-04 - learning_rate: 1.0000e-05
# Epoch 351/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6015e-04 - val_loss: 4.2062e-04 - learning_rate: 1.0000e-05
# Epoch 352/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1806e-04 - val_loss: 4.9089e-04 - learning_rate: 1.0000e-05
# Epoch 353/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5025e-04 - val_loss: 4.1390e-04 - learning_rate: 1.0000e-05
# Epoch 354/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7969e-04 - val_loss: 4.1017e-04 - learning_rate: 1.0000e-05
# Epoch 355/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5694e-04 - val_loss: 4.1834e-04 - learning_rate: 1.0000e-05
# Epoch 356/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5994e-04 - val_loss: 4.0937e-04 - learning_rate: 1.0000e-05
# Epoch 357/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2971e-04 - val_loss: 4.1690e-04 - learning_rate: 1.0000e-05
# Epoch 358/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3553e-04 - val_loss: 4.0734e-04 - learning_rate: 1.0000e-05
# Epoch 359/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8970e-04 - val_loss: 4.3004e-04 - learning_rate: 1.0000e-05
# Epoch 360/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5436e-04 - val_loss: 4.3261e-04 - learning_rate: 1.0000e-05
# Epoch 361/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7113e-04 - val_loss: 4.1989e-04 - learning_rate: 1.0000e-05
# Epoch 362/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4669e-04 - val_loss: 4.2378e-04 - learning_rate: 1.0000e-05
# Epoch 363/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5438e-04 - val_loss: 4.4729e-04 - learning_rate: 1.0000e-05
# Epoch 364/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9400e-04 - val_loss: 4.0492e-04 - learning_rate: 1.0000e-05
# Epoch 365/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5338e-04 - val_loss: 4.2444e-04 - learning_rate: 1.0000e-05
# Epoch 366/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3180e-04 - val_loss: 4.2327e-04 - learning_rate: 1.0000e-05
# Epoch 367/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4040e-04 - val_loss: 4.2068e-04 - learning_rate: 1.0000e-05
# Epoch 368/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2372e-04 - val_loss: 4.2315e-04 - learning_rate: 1.0000e-05
# Epoch 369/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5629e-04 - val_loss: 4.1041e-04 - learning_rate: 1.0000e-05
# Epoch 370/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6142e-04 - val_loss: 4.3268e-04 - learning_rate: 1.0000e-05
# Epoch 371/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6890e-04 - val_loss: 3.9579e-04 - learning_rate: 1.0000e-05
# Epoch 372/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3817e-04 - val_loss: 4.0048e-04 - learning_rate: 1.0000e-05
# Epoch 373/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5371e-04 - val_loss: 4.2400e-04 - learning_rate: 1.0000e-05
# Epoch 374/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3500e-04 - val_loss: 4.2419e-04 - learning_rate: 1.0000e-05
# Epoch 375/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6202e-04 - val_loss: 4.0332e-04 - learning_rate: 1.0000e-05
# Epoch 376/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7274e-04 - val_loss: 4.0038e-04 - learning_rate: 1.0000e-05
# Epoch 377/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3598e-04 - val_loss: 4.0481e-04 - learning_rate: 1.0000e-05
# Epoch 378/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5066e-04 - val_loss: 4.0245e-04 - learning_rate: 1.0000e-05
# Epoch 379/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4246e-04 - val_loss: 4.2331e-04 - learning_rate: 1.0000e-05
# Epoch 380/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5150e-04 - val_loss: 4.0287e-04 - learning_rate: 1.0000e-05
# Epoch 381/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3990e-04 - val_loss: 3.9895e-04 - learning_rate: 1.0000e-05
# Epoch 382/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5134e-04 - val_loss: 3.9539e-04 - learning_rate: 1.0000e-05
# Epoch 383/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5744e-04 - val_loss: 4.0193e-04 - learning_rate: 1.0000e-05
# Epoch 384/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4092e-04 - val_loss: 4.1083e-04 - learning_rate: 1.0000e-05
# Epoch 385/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7707e-04 - val_loss: 4.0907e-04 - learning_rate: 1.0000e-05
# Epoch 386/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1951e-04 - val_loss: 4.3905e-04 - learning_rate: 1.0000e-05
# Epoch 387/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4840e-04 - val_loss: 4.0226e-04 - learning_rate: 1.0000e-05
# Epoch 388/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6812e-04 - val_loss: 4.1196e-04 - learning_rate: 1.0000e-05
# Epoch 389/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6067e-04 - val_loss: 4.2930e-04 - learning_rate: 1.0000e-05
# Epoch 390/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4269e-04 - val_loss: 4.4590e-04 - learning_rate: 1.0000e-05
# Epoch 391/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4053e-04 - val_loss: 3.9800e-04 - learning_rate: 1.0000e-05
# Epoch 392/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3508e-04 - val_loss: 4.0993e-04 - learning_rate: 1.0000e-05
# Epoch 393/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3271e-04 - val_loss: 4.2677e-04 - learning_rate: 1.0000e-05
# Epoch 394/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6188e-04 - val_loss: 4.0072e-04 - learning_rate: 1.0000e-05
# Epoch 395/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3880e-04 - val_loss: 4.1033e-04 - learning_rate: 1.0000e-05
# Epoch 396/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5993e-04 - val_loss: 3.8700e-04 - learning_rate: 1.0000e-05
# Epoch 397/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4053e-04 - val_loss: 4.0180e-04 - learning_rate: 1.0000e-05
# Epoch 398/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5020e-04 - val_loss: 4.2792e-04 - learning_rate: 1.0000e-05
# Epoch 399/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6727e-04 - val_loss: 4.0191e-04 - learning_rate: 1.0000e-05
# Epoch 400/400
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4299e-04 - val_loss: 3.9178e-04 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 396.
#
# ✅ Moon Reverse Model trained and saved successfully.

# %%
# 1. طباعة الخسارة النهائية من تاريخ التدريب
train_loss = history_rev.history['loss'][-1]
val_loss   = history_rev.history['val_loss'][-1]
print(f"Final Train Loss : {train_loss:.5f}")
print(f"Final Val Loss   : {val_loss:.5f}")
print(f"Ratio (val/train): {val_loss / train_loss:.2f}x")

# 2. إجراء التنبؤ على بيانات الاختبار (المدخلات هنا هي المنحنيات والقيم الثابتة)
y_inv_pred_s = moon_reverse.predict([Xt_te_s, Xp_te_s, Xs_te_s], verbose=0)

# عكس التقييس (Inverse Transform) للحصول على الأبعاد الحقيقية
# نستخدم s_Y لأنه الـ Scaler الذي قمنا بتقييس الأبعاد به في هذه النوت بوك
y_inv_pred   = s_Y.inverse_transform(y_inv_pred_s)

# الأبعاد الحقيقية للاختبار (غير المقيسة)
y_inv_test   = Y_te 

# 3. حساب وعرض نسبة الخطأ لكل بُعد (MAE و MAPE)
# تم إضافة الـ Core Offset ليصبحوا 6 أبعاد
cols = ['Length', 'Diameter', 'Core_Diameter', 'Core_Offset', 'Throat_Diameter', 'Exit_Diameter']
print("\n--- Moon Inverse Model Evaluation ---")
for i, col in enumerate(cols):
    # حساب متوسط الخطأ المطلق (MAE) بالسنتيمتر
    mae  = np.mean(np.abs(y_inv_pred[:, i] - y_inv_test[:, i]))
    
    # حساب متوسط نسبة الخطأ المئوية (MAPE)
    mape = np.mean(np.abs(
        (y_inv_pred[:, i] - y_inv_test[:, i]) /
        (y_inv_test[:, i] + 1e-8) # إضافة رقم صغير لتجنب القسمة على صفر
    )) * 100
    
    print(f"  {col:<16}: MAE = {mae:.4f} cm  |  MAPE = {mape:.2f}%")

# 4. رسم منحنى التدريب (Training History Plot)
plt.figure(figsize=(10, 4))
plt.plot(history_rev.history['loss'],     label='Train Loss')
plt.plot(history_rev.history['val_loss'], label='Val Loss')
plt.title('Moon Reverse Model - Training History')
plt.xlabel('Epoch')
plt.ylabel('Loss (Huber)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Final Train Loss : 0.00034
# Final Val Loss   : 0.00039
# Ratio (val/train): 1.14x
#
# --- Moon Inverse Model Evaluation ---
#   Length          : MAE = 1.2785 cm  |  MAPE = 2.53%
#   Diameter        : MAE = 0.1455 cm  |  MAPE = 1.10%
#   Core_Diameter   : MAE = 0.1103 cm  |  MAPE = 2.99%
#   Core_Offset     : MAE = 0.0349 cm  |  MAPE = 2.20%
#   Throat_Diameter : MAE = 0.0040 cm  |  MAPE = 0.30%
#   Exit_Diameter   : MAE = 0.0071 cm  |  MAPE = 0.36%

# %%
# ===================================================================
# 7. Monte Carlo Dropout for Uncertainty Estimation (Moon Grain)
# ===================================================================

@tf.function
def predict_with_dropout(inputs):
    # 'training=True' forces Dropout layers to remain active during prediction
    return moon_reverse(inputs, training=True)

def mc_predict(t_in, p_in, s_in, n_iter=200):
    t_tensor = tf.constant(t_in, dtype=tf.float32)
    p_tensor = tf.constant(p_in, dtype=tf.float32)
    s_tensor = tf.constant(s_in, dtype=tf.float32)
    
    preds = []
    for _ in range(n_iter):
        # نقوم بتمرير training=True كـ argument مباشر لطبقات الـ Dropout
        out = moon_reverse([t_tensor, p_tensor, s_tensor], training=True) 
        preds.append(out.numpy())
        
    preds_arr = np.stack(preds, axis=0)
    return preds_arr.mean(axis=0), preds_arr.std(axis=0)

def show_uncertainty(sample_idx=0):
    # 1. استخراج عينة اختبار واحدة (3 مدخلات للموديل العكسي)
    t_s = Xt_te_s[sample_idx:sample_idx+1]
    p_s = Xp_te_s[sample_idx:sample_idx+1]
    s_s = Xs_te_s[sample_idx:sample_idx+1]
    
    # الأبعاد الحقيقية للاختبار (غير مقيسة)
    actual = Y_te[sample_idx] 
    
    # 2. الحصول على تنبؤات Monte Carlo (مقيسة)
    pred_mean_s, pred_std_s = mc_predict(t_s, p_s, s_s, n_iter=200)
    
    # 3. عكس التقييس (Inverse Transform)
    # عكس المتوسط للحصول على الأبعاد المتوقعة
    pred_vals = s_Y.inverse_transform(pred_mean_s)[0]
    
    # عكس الانحراف المعياري
    # ملاحظة: مع MinMaxScaler نقوم بالقسمة على الـ scale_ للحصول على التشتت الحقيقي
    pred_unc = pred_std_s[0] / s_Y.scale_
    
    # تم إضافة الـ Core Offset ليصبحوا 6 أبعاد
    DIM_NAMES = ['Length', 'Outer Dia', 'Inner Dia', 'Core Offset', 'Throat Dia', 'Exit Dia']
    
    # 4. طباعة النتائج في جدول منسق
    print(f"\n🎯 MC Dropout Uncertainty — Sample #{sample_idx}")
    print("=" * 75)
    print(f"{'Dimension':<16} {'Predicted':>10} {'±σ':>8} {'Actual':>10} "
          f"{'Err%':>8} {'Confidence'}")
    print("=" * 75)
    
    for i, name in enumerate(DIM_NAMES):
        actual_val = actual[i]
        err = abs(pred_vals[i] - actual_val) / (actual_val + 1e-9) * 100
        
        # معامل الاختلاف (CV) لتقييم مستوى الثقة
        cv   = pred_unc[i] / (abs(pred_vals[i]) + 1e-9) * 100
        conf = "🟢 High" if cv < 5 else ("🟡 Medium" if cv < 15 else "🔴 Low")
        
        print(f"{name:<16} {pred_vals[i]:>10.3f} {pred_unc[i]:>8.3f} "
              f"{actual_val:>10.3f} {err:>7.1f}%  {conf}")
              
    print("=" * 75)

    # 5. رسم بياني شريطي (Bar chart visualization)
    # تم تكبير العرض قليلاً ليستوعب 6 أعمدة
    fig, ax = plt.subplots(figsize=(12, 5))
    x     = np.arange(6)
    width = 0.35
    
    # أعمدة القيم الحقيقية والمتوقعة
    ax.bar(x - width/2, actual,    width, label='Actual',    color='royalblue', alpha=0.85)
    ax.bar(x + width/2, pred_vals, width, label='Predicted', color='tomato',    alpha=0.85,
           yerr=pred_unc, capsize=6, error_kw={'linewidth': 2})
           
    ax.set_xticks(x)
    ax.set_xticklabels(DIM_NAMES, rotation=15, fontsize=10)
    ax.set_title(f'Moon Grain Dimensions — Sample #{sample_idx}\n'
                 f'(Error bars represent MC Dropout Uncertainty)',
                 fontsize=12, fontweight='bold')
    ax.legend(fontsize=10)
    ax.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    # plt.savefig(f'moon_inverse_uncertainty_{sample_idx}.png', dpi=150)
    plt.show()

# ==========================================
# تشغيل الدالة على بعض العينات
show_uncertainty(0)
show_uncertainty(35)
show_uncertainty(99)
# Out:
# 🎯 MC Dropout Uncertainty — Sample #0
# ===========================================================================
# Dimension         Predicted       ±σ     Actual     Err% Confidence
# ===========================================================================
# Length              117.207    0.000    120.000     2.3%  🟢 High
# Outer Dia            16.070    0.000     16.000     0.4%  🟢 High
# Inner Dia             3.087    0.000      3.000     2.9%  🟢 High
# Core Offset           3.988    0.000      4.000     0.3%  🟢 High
# Throat Dia            1.997    0.000      2.000     0.1%  🟢 High
# Exit Dia              3.005    0.000      3.000     0.2%  🟢 High
# ===========================================================================
# 🎯 MC Dropout Uncertainty — Sample #35
# ===========================================================================
# Dimension         Predicted       ±σ     Actual     Err% Confidence
# ===========================================================================
# Length              116.752    0.000    120.000     2.7%  🟢 High
# Outer Dia            14.169    0.000     14.000     1.2%  🟢 High
# Inner Dia             3.129    0.000      3.000     4.3%  🟢 High
# Core Offset           1.975    0.000      2.000     1.3%  🟢 High
# Throat Dia            2.002    0.000      2.000     0.1%  🟢 High
# Exit Dia              3.014    0.000      3.000     0.5%  🟢 High
# ===========================================================================
# 🎯 MC Dropout Uncertainty — Sample #99
# ===========================================================================
# Dimension         Predicted       ±σ     Actual     Err% Confidence
# ===========================================================================
# Length               30.725    0.000     30.000     2.4%  🟢 High
# Outer Dia            15.985    0.000     16.000     0.1%  🟢 High
# Inner Dia             1.999    0.000      2.000     0.0%  🟢 High
# Core Offset           1.004    0.000      1.000     0.4%  🟢 High
# Throat Dia            0.796    0.000      0.800     0.6%  🟢 High
# Exit Dia              1.204    0.000      1.200     0.4%  🟢 High
# ===========================================================================

# %%
import os
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import trapezoid 
from scipy.signal import savgol_filter
from scipy.interpolate import interp1d

def predict_moon_dimensions_from_file_v2(file_path):
    print(f"\n🔍 Reading file: {file_path}")

    # 1. تحميل الموديل والمقاييس (تأكد من وجود هذه الملفات في المسار)
    try:
        max_vals = joblib.load('moon_rev_max_values.pkl')
        s_xs = joblib.load('moon_rev_scaler_scalars.pkl')
        s_Y = joblib.load('moon_rev_scaler_dims.pkl')
        xt_max = max_vals['xt_max']
        xp_max = max_vals['xp_max']
    except Exception as e:
        print(f"❌ Error loading scalers: {e}")
        return

    # 2. قراءة الملف (Excel أو CSV)
    if file_path.endswith('.xlsx') or file_path.endswith('.xls'):
        df = pd.read_excel(file_path)
    else:
        df = pd.read_csv(file_path, sep=None, engine='python', encoding='latin1', on_bad_lines='skip')
    
    # 3. التعرف الذكي على الأعمدة
    col_map = {}
    for col in df.columns:
        c = str(col).lower().replace(' ', '').replace('_', '').replace('(', '').replace(')', '')
        if 'time' in c or c == 't': col_map['time'] = col
        elif 'thrust' in c or c == 'f': col_map['thrust'] = col
        elif 'pressure' in c or c == 'p': col_map['pressure'] = col
        elif 'isp' in c: col_map['isp'] = col

    # 4. معالجة البيانات (تنظيف + استيفاء لـ 100 نقطة)
    df = df.sort_values(col_map['time']).dropna(subset=[col_map['time'], col_map['thrust'], col_map['pressure']])
    t, thrust, pressure = df[col_map['time']].values, df[col_map['thrust']].values, df[col_map['pressure']].values
    
    x_new = np.linspace(t[0], t[-1], 100)
    t_100 = interp1d(t, thrust, kind='linear', fill_value='extrapolate')(x_new)
    p_100 = interp1d(t, pressure, kind='linear', fill_value='extrapolate')(x_new)

    # 5. حساب الثوابت (Scalars)
    isp = df[col_map['isp']].iloc[0] if 'isp' in col_map else 220.0
    scalars = np.array([[isp, trapezoid(thrust, t), t[-1], np.max(thrust)]])

    # ⚠️ الخطوة الأهم: التقييس الفيزيائي (يجب أن يطابق ما فعلناه في التدريب)
    t_scaled = (t_100 / xt_max).reshape(1, -1)
    p_scaled = (p_100 / xp_max).reshape(1, -1)
    s_scaled = s_xs.transform(scalars)

    # 6. التنبؤ
    pred_scaled = moon_reverse.predict([t_scaled, p_scaled, s_scaled], verbose=0)
    pred_dims = s_Y.inverse_transform(pred_scaled)[0]
    pred_dims = np.maximum(pred_dims, 0.01) # صمام أمان

    # 7. عرض النتائج
    DIM_LABELS = ['Length', 'Diameter', 'Core_Dia', 'Core_Offset', 'Throat_Dia', 'Exit_Dia']
    print("\n" + "="*50)
    print(f"{'Dimension':<20} | {'Predicted Value (cm)':<20}")
    print("-" * 50)
    for label, val in zip(DIM_LABELS, pred_dims):
        print(f"{label:<20} | {val:>10.4f}")
    print("="*50)

    return dict(zip(DIM_LABELS, pred_dims))

# لتشغيل الكود:
result = predict_moon_dimensions_from_file_v2('/kaggle/input/datasets/mahmoudabdelrazek11/train1/1029.0.xlsx')
# Out:
# 🔍 Reading file: /kaggle/input/datasets/mahmoudabdelrazek11/train1/1029.0.xlsx
#
# ==================================================
# Dimension            | Predicted Value (cm)
# --------------------------------------------------
# Length               |    38.7357
# Diameter             |    14.6609
# Core_Dia             |     4.6391
# Core_Offset          |     2.6760
# Throat_Dia           |     0.9613
# Exit_Dia             |     1.2952
# ==================================================
