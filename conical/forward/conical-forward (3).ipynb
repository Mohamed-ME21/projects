# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
import os
from scipy.interpolate import interp1d
from scipy.signal import savgol_filter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

print("TensorFlow Version:", tf.__version__)
# Out:
# 2026-05-18 15:29:14.094413: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779118154.501147      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779118154.623065      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779118155.699527      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779118155.699572      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779118155.699575      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779118155.699577      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow Version: 2.19.0

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/datasets/mohamedesh/data-conical/Conical_Dataset.csv")  # أو read_excel لو xlsx

# أسماء الأعمدة
print("Columns:", df.columns.tolist())

# أول 5 صفوف في time و thrust
print(df[['Time (s)', 'Thrust (N)']].head())  # غيّر أسماء الأعمدة لو مختلفة

# فحص الـ noise
print("\nBasic Stats:")
print(df.describe())

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Columns: ['Time (s)', 'Pressure (MPa)', 'Thrust (N)', 'Length', 'Diameter', 'Forward_Core_Diameter', 'Aft_Core_Diameter', 'Throat_Diameter', 'Exit_Diameter', 'Total Impulse (Ns)', 'ISP (s)', 'Max Thrust (N)', 'Peak Pressure (MPa)', 'Burn Time (s)', 'Avg Thrust (N)', 'Model_ID']
#    Time (s)  Thrust (N)
# 0     0.000    0.000000
# 1     0.005  161.561641
# 2     0.010  162.244399
# 3     0.015  162.929600
# 4     0.020  163.617251
#
# Basic Stats:
#            Time (s)  Pressure (MPa)    Thrust (N)        Length      Diameter  \
# count  3.847881e+06    3.847881e+06  3.847881e+06  3.847881e+06  3.847881e+06
# mean   3.642640e+00    2.627137e+00  1.137599e+03  6.811736e+01  8.848723e+00
# std    2.534293e+00    1.909310e+00  1.086771e+03  3.556368e+01  2.066840e+00
# min    0.000000e+00    0.000000e+00  0.000000e+00  2.000000e+01  4.000000e+00
# 25%    1.570000e+00    7.844254e-01  2.458715e+02  4.000000e+01  8.000000e+00
# 50%    3.230000e+00    2.443967e+00  8.492971e+02  6.000000e+01  8.000000e+00
# 75%    5.310000e+00    4.139656e+00  1.690327e+03  1.000000e+02  1.000000e+01
# max    1.365500e+01    7.463976e+00  6.572649e+03  1.300000e+02  1.600000e+01
#
#        Forward_Core_Diameter  Aft_Core_Diameter  Throat_Diameter  \
# count           3.847881e+06       3.847881e+06     3.847881e+06
# mean            2.550989e+00       6.941455e+00     2.021934e+00
# std             1.364942e+00       1.863623e+00     4.734180e-01
# min             1.000000e+00       2.500000e+00     8.000000e-01
# 25%             1.500000e+00       5.000000e+00     1.700000e+00
# 50%             2.000000e+00       7.000000e+00     2.000000e+00
# 75%             3.500000e+00       8.500000e+00     2.400000e+00
# max             6.000000e+00       1.000000e+01     2.900000e+00
#
#        Exit_Diameter  Total Impulse (Ns)       ISP (s)  Max Thrust (N)  \
# count   3.847881e+06        3.847881e+06  3.847881e+06    3.847881e+06
# mean    3.032901e+00        8.043644e+03  1.673530e+02    2.636863e+03
# std     7.101271e-01        4.604542e+03  2.892339e+00    1.318508e+03
# min     1.200000e+00        3.853016e+02  1.528123e+02    3.467810e+02
# 25%     2.550000e+00        4.653975e+03  1.658141e+02    1.612162e+03
# 50%     3.000000e+00        6.930322e+03  1.680488e+02    2.367625e+03
# 75%     3.600000e+00        1.061844e+04  1.694112e+02    3.476919e+03
# max     4.350000e+00        2.589118e+04  1.740863e+02    6.572649e+03
#
#        Peak Pressure (MPa)  Burn Time (s)  Avg Thrust (N)      Model_ID
# count         3.847881e+06   3.847881e+06    3.847881e+06  3.847881e+06
# mean          5.878477e+00   7.285280e+00    1.137599e+03  1.637921e+03
# std           1.102539e+00   2.445583e+00    5.680177e+02  9.906946e+02
# min           2.384012e+00   1.190000e+00    1.486149e+02  1.000000e+00
# 25%           5.074748e+00   5.450000e+00    6.973386e+02  7.660000e+02
# 50%           6.038227e+00   7.305000e+00    1.031472e+03  1.578000e+03
# 75%           6.822998e+00   9.110000e+00    1.500694e+03  2.514000e+03
# max           7.463976e+00   1.365500e+01    3.462533e+03  3.391000e+03
#
# Missing values:
# Time (s)                 0
# Pressure (MPa)           0
# Thrust (N)               0
# Length                   0
# Diameter                 0
# Forward_Core_Diameter    0
# Aft_Core_Diameter        0
# Throat_Diameter          0
# Exit_Diameter            0
# Total Impulse (Ns)       0
# ISP (s)                  0
# Max Thrust (N)           0
# Peak Pressure (MPa)      0
# Burn Time (s)            0
# Avg Thrust (N)           0
# Model_ID                 0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/kaggle/input/datasets/mohamedesh/data-conical/Conical_Dataset.csv")  # غيّر الاسم

# أول 10 Model_IDs
first_10_models = sorted(df['Model_ID'].unique())[:10]
df_10 = df[df['Model_ID'].isin(first_10_models)]

# الرسم
fig, axes = plt.subplots(2, 5, figsize=(18, 7))
axes = axes.flatten()

for i, model_id in enumerate(first_10_models):
    model_data = df_10[df_10['Model_ID'] == model_id]
    
    axes[i].plot(model_data['Time (s)'], model_data['Thrust (N)'], 
                 color='royalblue', linewidth=1.5)
    axes[i].set_title(f'Model {int(model_id)}', fontsize=11, fontweight='bold')
    axes[i].set_xlabel('Time (s)', fontsize=9)
    axes[i].set_ylabel('Thrust (N)', fontsize=9)
    axes[i].grid(True, alpha=0.3)
    axes[i].fill_between(model_data['Time (s)'], model_data['Thrust (N)'], 
                          alpha=0.15, color='royalblue')

plt.suptitle('Thrust Profiles — First 10 Models', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
# plt.savefig('thrust_profiles.png', dpi=150, bbox_inches='tight')
plt.show()
# print("✅ تم الحفظ: thrust_profiles.png")

# %%
def process_conical_data(file_path, num_points=100):
    if not os.path.exists(file_path): 
        raise FileNotFoundError(f'File not found: {file_path}')
        
    # قراءة الملف وتجاوز الأخطاء
    df = pd.read_csv(file_path, on_bad_lines='skip', skip_blank_lines=True)
    df.columns = df.columns.str.strip()
    df['Model_ID'] = pd.to_numeric(df['Model_ID'], errors='coerce')
    
    ids = df['Model_ID'].unique()
    X, y_thrust, y_pressure, y_scalars = [], [], [], []

    # أسماء الأعمدة الـ 6 للـ Moon Grain
    input_cols = ['Length', 'Diameter', 'Forward_Core_Diameter', 'Aft_Core_Diameter', 'Throat_Diameter', 'Exit_Diameter']

    for uid in ids:
        try:
            case_data = df[df['Model_ID'] == uid].sort_values('Time (s)')
            
            # سحب الأبعاد الستة
            inputs = case_data[input_cols].iloc[0].values
            t = case_data['Time (s)'].values
            
            if len(t) < 2 or t[-1] <= 0 or np.any(inputs <= 0): 
                continue

            thrust = case_data['Thrust (N)'].fillna(0).values
            pressure = case_data['Pressure (MPa)'].fillna(0).values

            # تنعيم المنحنيات
            if len(thrust) > 7:
                thrust = savgol_filter(thrust, window_length=7, polyorder=3)
                pressure = savgol_filter(pressure, window_length=7, polyorder=3)

            # توحيد طول المنحنيات لـ 100 نقطة
            x_new = np.linspace(t[0], t[-1], num_points)
            X.append(inputs)
            y_thrust.append(interp1d(t, thrust, kind='linear', fill_value='extrapolate')(x_new))
            y_pressure.append(interp1d(t, pressure, kind='linear', fill_value='extrapolate')(x_new))
            
            # سحب القيم الثابتة (ISP, Total Impulse, Burn Time, Max Thrust)
            y_scalars.append([
                case_data['ISP (s)'].iloc[0], 
                case_data['Total Impulse (Ns)'].iloc[0], 
                t[-1], 
                np.max(thrust)
            ])
            
        except Exception: 
            continue
        
    return np.array(X), np.array(y_thrust), np.array(y_pressure), np.array(y_scalars)

# ==========================================
# استدعاء ملف الـ CSV الخاص بـ Moon Grain
# ==========================================
file_path = '/kaggle/input/datasets/mohamedesh/data-conical/Conical_Dataset.csv' # ضع المسار الصحيح هنا
X, yt, yp, ys = process_conical_data(file_path) 
X, yt, yp, ys = X.astype(float), yt.astype(float), yp.astype(float), ys.astype(float)

# توحيد الأطوال لتجنب أي أخطاء
min_s = min(len(X), len(yt), len(yp), len(ys))
X, yt, yp, ys = X[:min_s], yt[:min_s], yp[:min_s], ys[:min_s]

print(f"✅ Conical Data loaded successfully: {len(X)} cases.")
print(f"Input shape (X): {X.shape}") # يجب أن يكون (N, 6)
# Out:
# ✅ Conical Data loaded successfully: 3065 cases.
# Input shape (X): (3065, 6)

# %%
# تقسيم البيانات
X_train, X_test, yt_train, yt_test, yp_train, yp_test, ys_train, ys_test = train_test_split(
    X, yt, yp, ys, test_size=0.15, random_state=42
)

from sklearn.preprocessing import MinMaxScaler
import joblib

# 1. تقييس الأبعاد (المدخلات)
s_X = MinMaxScaler()
X_tr_s = s_X.fit_transform(X_train)
X_te_s = s_X.transform(X_test)

# 2. الخدعة الفيزيائية (Global Max Scaling للمنحنيات)
# هذا يحافظ على القمم الحادة للـ Moon Burner ولا يشوهها
yt_max = np.max(yt_train)
yp_max = np.max(yp_train)

yt_tr_s = yt_train / yt_max
yt_te_s = yt_test / yt_max

yp_tr_s = yp_train / yp_max
yp_te_s = yp_test / yp_max

# 3. تقييس القيم الثابتة
s_ys = MinMaxScaler()
ys_tr_s = s_ys.fit_transform(ys_train)
ys_te_s = s_ys.transform(ys_test)

# حفظ المقاييس الجديدة
joblib.dump(s_X, 'con_fwd_scaler_X.pkl')
joblib.dump(s_ys, 'con_fwd_scaler_scalars.pkl')
joblib.dump({'yt_max': yt_max, 'yp_max': yp_max}, 'con_fwd_max_values.pkl')

print("✅ Smart Physical Scaling Applied!")
# Out:
# ✅ Smart Physical Scaling Applied!

# %%
from tensorflow.keras.layers import RepeatVector, TimeDistributed, GRU, Flatten

def build_conical_forward_model_gru():
    inputs = layers.Input(shape=(6,), name='Conical_Dimensions_Input')

    # 1. استخراج الخصائص الهندسية (Encoder)
    x = layers.Dense(128, activation='elu')(inputs)
    x = layers.Dense(256, activation='elu')(x)
    latent_vector = layers.Dense(64, activation='elu')(x)

    # 2. تحويل الأبعاد إلى تسلسل زمني (Vector to Sequence)
    # تكرار الخصائص 100 مرة لتمهيد الطريق لشبكات الذاكرة
    seq_input = RepeatVector(100)(latent_vector)

    # 3. مسار منحنى الدفع (استخدام GRU)
    # الـ GRU سيفهم التتابع الزمني ويرسم خط الثبات (Plateau) بنعومة فائقة
    b_t = GRU(128, return_sequences=True, activation='tanh')(seq_input)
    b_t = GRU(64, return_sequences=True, activation='tanh')(b_t)
    out_t_seq = TimeDistributed(layers.Dense(1, activation='linear'))(b_t)
    out_thrust = Flatten(name='Thrust_Output')(out_t_seq) # إعادتها لشكل 100 نقطة

    # 4. مسار منحنى الضغط (استخدام GRU)
    b_p = GRU(128, return_sequences=True, activation='tanh')(seq_input)
    b_p = GRU(64, return_sequences=True, activation='tanh')(b_p)
    out_p_seq = TimeDistributed(layers.Dense(1, activation='linear'))(b_p)
    out_pressure = Flatten(name='Pressure_Output')(out_p_seq)

    # 5. مسار القيم الثابتة (يظل Dense لأنه لا يحتاج زمناً)
    b_s = layers.Dense(32, activation='elu')(latent_vector)
    out_scalars = layers.Dense(4, activation='sigmoid', name='Scalars_Output')(b_s)

    model = Model(inputs=inputs, outputs=[out_thrust, out_pressure, out_scalars])
    
    # استخدام MSE مع الـ GRU يعطي نتائج استثنائية في المنحنيات
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
    
    return model

moon_forward = build_conical_forward_model_gru()
moon_forward.summary()
# Out:
# I0000 00:00:1779118246.157109      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1779118246.162899      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Conical_Dimensions… │ (None, 6)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │        896 │ Conical_Dimensio… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │     33,024 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │     16,448 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector       │ (None, 100, 64)   │          0 │ dense_2[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 100, 128)  │     74,496 │ repeat_vector[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_2 (GRU)         │ (None, 100, 128)  │     74,496 │ repeat_vector[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_1 (GRU)         │ (None, 100, 64)   │     37,248 │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_3 (GRU)         │ (None, 100, 64)   │     37,248 │ gru_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, 100, 1)    │         65 │ gru_1[0][0]       │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_1  │ (None, 100, 1)    │         65 │ gru_3[0][0]       │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 32)        │      2,080 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Thrust_Output       │ (None, 100)       │          0 │ time_distributed… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Pressure_Output     │ (None, 100)       │          0 │ time_distributed… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Scalars_Output      │ (None, 4)         │        132 │ dense_5[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 276,198 (1.05 MB)
#  Trainable params: 276,198 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# إعداد متحكمات التدريب
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-5, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

print("Starting training for Moon Forward Model...")
history_fwd = moon_forward.fit(
    x=X_tr_s, 
    y={'Thrust_Output': yt_tr_s, 'Pressure_Output': yp_tr_s, 'Scalars_Output': ys_tr_s},
    validation_split=0.15,
    epochs=400,
    batch_size=32,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)
# Out:
# Starting training for Moon Forward Model...
# Epoch 1/400
# I0000 00:00:1779118260.042842     140 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 18s 83ms/step - Pressure_Output_loss: 0.0867 - Scalars_Output_loss: 0.0340 - Thrust_Output_loss: 0.0291 - loss: 0.1498 - val_Pressure_Output_loss: 0.0650 - val_Scalars_Output_loss: 0.0136 - val_Thrust_Output_loss: 0.0210 - val_loss: 0.0985 - learning_rate: 0.0010
# Epoch 2/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0509 - Scalars_Output_loss: 0.0128 - Thrust_Output_loss: 0.0189 - loss: 0.0826 - val_Pressure_Output_loss: 0.0208 - val_Scalars_Output_loss: 0.0074 - val_Thrust_Output_loss: 0.0073 - val_loss: 0.0336 - learning_rate: 0.0010
# Epoch 3/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0160 - Scalars_Output_loss: 0.0068 - Thrust_Output_loss: 0.0067 - loss: 0.0295 - val_Pressure_Output_loss: 0.0089 - val_Scalars_Output_loss: 0.0047 - val_Thrust_Output_loss: 0.0032 - val_loss: 0.0155 - learning_rate: 0.0010
# Epoch 4/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 0.0093 - Scalars_Output_loss: 0.0049 - Thrust_Output_loss: 0.0034 - loss: 0.0176 - val_Pressure_Output_loss: 0.0085 - val_Scalars_Output_loss: 0.0039 - val_Thrust_Output_loss: 0.0049 - val_loss: 0.0168 - learning_rate: 0.0010
# Epoch 5/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0057 - Scalars_Output_loss: 0.0037 - Thrust_Output_loss: 0.0026 - loss: 0.0120 - val_Pressure_Output_loss: 0.0040 - val_Scalars_Output_loss: 0.0026 - val_Thrust_Output_loss: 0.0025 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 6/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0038 - Scalars_Output_loss: 0.0027 - Thrust_Output_loss: 0.0019 - loss: 0.0083 - val_Pressure_Output_loss: 0.0032 - val_Scalars_Output_loss: 0.0022 - val_Thrust_Output_loss: 0.0012 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 7/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 0.0027 - Scalars_Output_loss: 0.0020 - Thrust_Output_loss: 0.0012 - loss: 0.0059 - val_Pressure_Output_loss: 0.0024 - val_Scalars_Output_loss: 0.0017 - val_Thrust_Output_loss: 0.0015 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 8/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0022 - Scalars_Output_loss: 0.0017 - Thrust_Output_loss: 0.0010 - loss: 0.0049 - val_Pressure_Output_loss: 0.0026 - val_Scalars_Output_loss: 0.0013 - val_Thrust_Output_loss: 8.8278e-04 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 9/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0035 - Scalars_Output_loss: 0.0017 - Thrust_Output_loss: 0.0014 - loss: 0.0066 - val_Pressure_Output_loss: 0.0019 - val_Scalars_Output_loss: 0.0013 - val_Thrust_Output_loss: 0.0011 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 10/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 0.0020 - Scalars_Output_loss: 0.0014 - Thrust_Output_loss: 9.4560e-04 - loss: 0.0043 - val_Pressure_Output_loss: 0.0019 - val_Scalars_Output_loss: 0.0012 - val_Thrust_Output_loss: 7.1883e-04 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 11/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 0.0016 - Scalars_Output_loss: 0.0012 - Thrust_Output_loss: 6.9923e-04 - loss: 0.0035 - val_Pressure_Output_loss: 0.0022 - val_Scalars_Output_loss: 0.0013 - val_Thrust_Output_loss: 8.9334e-04 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 12/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0023 - Scalars_Output_loss: 0.0014 - Thrust_Output_loss: 0.0010 - loss: 0.0047 - val_Pressure_Output_loss: 0.0027 - val_Scalars_Output_loss: 0.0011 - val_Thrust_Output_loss: 0.0018 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 13/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0016 - Scalars_Output_loss: 0.0012 - Thrust_Output_loss: 8.8285e-04 - loss: 0.0037 - val_Pressure_Output_loss: 0.0011 - val_Scalars_Output_loss: 0.0013 - val_Thrust_Output_loss: 7.4071e-04 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 14/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0012 - Scalars_Output_loss: 0.0011 - Thrust_Output_loss: 4.8269e-04 - loss: 0.0028 - val_Pressure_Output_loss: 0.0012 - val_Scalars_Output_loss: 9.8220e-04 - val_Thrust_Output_loss: 3.6826e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 15/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0014 - Scalars_Output_loss: 0.0010 - Thrust_Output_loss: 6.8438e-04 - loss: 0.0031 - val_Pressure_Output_loss: 0.0010 - val_Scalars_Output_loss: 0.0011 - val_Thrust_Output_loss: 4.1403e-04 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 16/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 8.5721e-04 - Scalars_Output_loss: 0.0010 - Thrust_Output_loss: 4.0421e-04 - loss: 0.0023 - val_Pressure_Output_loss: 0.0017 - val_Scalars_Output_loss: 9.8716e-04 - val_Thrust_Output_loss: 5.1378e-04 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 17/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 8.2200e-04 - Scalars_Output_loss: 9.7901e-04 - Thrust_Output_loss: 4.3633e-04 - loss: 0.0022 - val_Pressure_Output_loss: 0.0017 - val_Scalars_Output_loss: 9.2699e-04 - val_Thrust_Output_loss: 2.2687e-04 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 18/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 0.0010 - Scalars_Output_loss: 9.1398e-04 - Thrust_Output_loss: 5.5476e-04 - loss: 0.0025 - val_Pressure_Output_loss: 0.0106 - val_Scalars_Output_loss: 0.0024 - val_Thrust_Output_loss: 0.0046 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 19/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0036 - Scalars_Output_loss: 0.0013 - Thrust_Output_loss: 0.0018 - loss: 0.0066 - val_Pressure_Output_loss: 0.0013 - val_Scalars_Output_loss: 8.8612e-04 - val_Thrust_Output_loss: 9.6335e-04 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 20/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 0.0011 - Scalars_Output_loss: 9.8019e-04 - Thrust_Output_loss: 6.1293e-04 - loss: 0.0027 - val_Pressure_Output_loss: 0.0020 - val_Scalars_Output_loss: 7.7671e-04 - val_Thrust_Output_loss: 8.2502e-04 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 21/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - Pressure_Output_loss: 0.0016 - Scalars_Output_loss: 9.5430e-04 - Thrust_Output_loss: 5.8683e-04 - loss: 0.0031 - val_Pressure_Output_loss: 8.3062e-04 - val_Scalars_Output_loss: 8.8940e-04 - val_Thrust_Output_loss: 3.8662e-04 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 22/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - Pressure_Output_loss: 7.0399e-04 - Scalars_Output_loss: 9.1473e-04 - Thrust_Output_loss: 3.6678e-04 - loss: 0.0020 - val_Pressure_Output_loss: 5.9694e-04 - val_Scalars_Output_loss: 7.9954e-04 - val_Thrust_Output_loss: 3.0287e-04 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 23/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - Pressure_Output_loss: 5.6565e-04 - Scalars_Output_loss: 8.6287e-04 - Thrust_Output_loss: 2.7267e-04 - loss: 0.0017 - val_Pressure_Output_loss: 0.0026 - val_Scalars_Output_loss: 0.0011 - val_Thrust_Output_loss: 2.5920e-04 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 24/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0014 - Scalars_Output_loss: 9.1557e-04 - Thrust_Output_loss: 4.3658e-04 - loss: 0.0028 - val_Pressure_Output_loss: 0.0014 - val_Scalars_Output_loss: 9.8433e-04 - val_Thrust_Output_loss: 3.8214e-04 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 25/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 8.5025e-04 - Scalars_Output_loss: 8.2837e-04 - Thrust_Output_loss: 3.1085e-04 - loss: 0.0020 - val_Pressure_Output_loss: 4.6096e-04 - val_Scalars_Output_loss: 7.2338e-04 - val_Thrust_Output_loss: 3.8647e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 26/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.0980e-04 - Scalars_Output_loss: 8.3262e-04 - Thrust_Output_loss: 2.4597e-04 - loss: 0.0017 - val_Pressure_Output_loss: 0.0011 - val_Scalars_Output_loss: 7.1204e-04 - val_Thrust_Output_loss: 4.2237e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 27/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0010 - Scalars_Output_loss: 8.6750e-04 - Thrust_Output_loss: 4.5208e-04 - loss: 0.0023 - val_Pressure_Output_loss: 4.3938e-04 - val_Scalars_Output_loss: 6.8914e-04 - val_Thrust_Output_loss: 2.1953e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 28/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 4.3889e-04 - Scalars_Output_loss: 7.2509e-04 - Thrust_Output_loss: 2.0457e-04 - loss: 0.0014 - val_Pressure_Output_loss: 5.4249e-04 - val_Scalars_Output_loss: 0.0013 - val_Thrust_Output_loss: 0.0010 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 29/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0011 - Scalars_Output_loss: 8.8667e-04 - Thrust_Output_loss: 4.3797e-04 - loss: 0.0024 - val_Pressure_Output_loss: 0.0025 - val_Scalars_Output_loss: 0.0010 - val_Thrust_Output_loss: 0.0016 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 30/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0014 - Scalars_Output_loss: 8.5541e-04 - Thrust_Output_loss: 5.8910e-04 - loss: 0.0028 - val_Pressure_Output_loss: 7.3830e-04 - val_Scalars_Output_loss: 6.5071e-04 - val_Thrust_Output_loss: 1.6766e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 31/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.3345e-04 - Scalars_Output_loss: 7.3153e-04 - Thrust_Output_loss: 2.3160e-04 - loss: 0.0016 - val_Pressure_Output_loss: 0.0020 - val_Scalars_Output_loss: 8.0772e-04 - val_Thrust_Output_loss: 0.0013 - val_loss: 0.0038 - learning_rate: 0.0010
# Epoch 32/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0023 - Scalars_Output_loss: 8.7535e-04 - Thrust_Output_loss: 9.6734e-04 - loss: 0.0042 - val_Pressure_Output_loss: 5.7257e-04 - val_Scalars_Output_loss: 6.1995e-04 - val_Thrust_Output_loss: 1.2418e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 33/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.8215e-04 - Scalars_Output_loss: 6.2917e-04 - Thrust_Output_loss: 1.6523e-04 - loss: 0.0012 - val_Pressure_Output_loss: 7.7126e-04 - val_Scalars_Output_loss: 6.9028e-04 - val_Thrust_Output_loss: 2.6299e-04 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 34/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 4.1580e-04 - Scalars_Output_loss: 6.6201e-04 - Thrust_Output_loss: 1.8055e-04 - loss: 0.0013 - val_Pressure_Output_loss: 6.3756e-04 - val_Scalars_Output_loss: 6.0749e-04 - val_Thrust_Output_loss: 1.3959e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 35/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0010 - Scalars_Output_loss: 7.3867e-04 - Thrust_Output_loss: 3.4205e-04 - loss: 0.0021 - val_Pressure_Output_loss: 0.0010 - val_Scalars_Output_loss: 7.0941e-04 - val_Thrust_Output_loss: 2.0103e-04 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 36/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.6151e-04 - Scalars_Output_loss: 7.2806e-04 - Thrust_Output_loss: 1.9580e-04 - loss: 0.0015 - val_Pressure_Output_loss: 0.0026 - val_Scalars_Output_loss: 8.5818e-04 - val_Thrust_Output_loss: 0.0013 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 37/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Pressure_Output_loss: 0.0037 - Scalars_Output_loss: 0.0013 - Thrust_Output_loss: 0.0014 - loss: 0.0064
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 0.0037 - Scalars_Output_loss: 0.0013 - Thrust_Output_loss: 0.0014 - loss: 0.0064 - val_Pressure_Output_loss: 6.3525e-04 - val_Scalars_Output_loss: 6.1952e-04 - val_Thrust_Output_loss: 3.1883e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 38/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 4.3830e-04 - Scalars_Output_loss: 6.6354e-04 - Thrust_Output_loss: 1.8110e-04 - loss: 0.0013 - val_Pressure_Output_loss: 2.1619e-04 - val_Scalars_Output_loss: 5.8647e-04 - val_Thrust_Output_loss: 6.5872e-05 - val_loss: 8.2843e-04 - learning_rate: 5.0000e-04
# Epoch 39/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.3072e-04 - Scalars_Output_loss: 6.3412e-04 - Thrust_Output_loss: 8.8392e-05 - loss: 9.5285e-04 - val_Pressure_Output_loss: 2.3295e-04 - val_Scalars_Output_loss: 6.0078e-04 - val_Thrust_Output_loss: 8.2913e-05 - val_loss: 8.7265e-04 - learning_rate: 5.0000e-04
# Epoch 40/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 1.8936e-04 - Scalars_Output_loss: 5.4832e-04 - Thrust_Output_loss: 6.9683e-05 - loss: 8.0724e-04 - val_Pressure_Output_loss: 2.0241e-04 - val_Scalars_Output_loss: 5.7839e-04 - val_Thrust_Output_loss: 6.0221e-05 - val_loss: 8.0124e-04 - learning_rate: 5.0000e-04
# Epoch 41/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 1.5869e-04 - Scalars_Output_loss: 5.4512e-04 - Thrust_Output_loss: 5.4600e-05 - loss: 7.5851e-04 - val_Pressure_Output_loss: 1.9355e-04 - val_Scalars_Output_loss: 6.3080e-04 - val_Thrust_Output_loss: 8.6258e-05 - val_loss: 8.5847e-04 - learning_rate: 5.0000e-04
# Epoch 42/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - Pressure_Output_loss: 1.5787e-04 - Scalars_Output_loss: 5.7422e-04 - Thrust_Output_loss: 7.4243e-05 - loss: 8.0642e-04 - val_Pressure_Output_loss: 2.4338e-04 - val_Scalars_Output_loss: 5.8557e-04 - val_Thrust_Output_loss: 6.1636e-05 - val_loss: 8.5054e-04 - learning_rate: 5.0000e-04
# Epoch 43/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 1.5073e-04 - Scalars_Output_loss: 5.5070e-04 - Thrust_Output_loss: 5.2433e-05 - loss: 7.5368e-04 - val_Pressure_Output_loss: 3.7684e-04 - val_Scalars_Output_loss: 6.3476e-04 - val_Thrust_Output_loss: 1.4769e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 44/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.3453e-04 - Scalars_Output_loss: 5.4178e-04 - Thrust_Output_loss: 9.4311e-05 - loss: 8.7075e-04 - val_Pressure_Output_loss: 1.6372e-04 - val_Scalars_Output_loss: 5.5819e-04 - val_Thrust_Output_loss: 3.6239e-05 - val_loss: 7.1670e-04 - learning_rate: 5.0000e-04
# Epoch 45/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.5944e-04 - Scalars_Output_loss: 5.5928e-04 - Thrust_Output_loss: 5.4058e-05 - loss: 7.7278e-04 - val_Pressure_Output_loss: 1.6925e-04 - val_Scalars_Output_loss: 5.4372e-04 - val_Thrust_Output_loss: 8.3490e-05 - val_loss: 7.5922e-04 - learning_rate: 5.0000e-04
# Epoch 46/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.3440e-04 - Scalars_Output_loss: 5.2425e-04 - Thrust_Output_loss: 5.8220e-05 - loss: 7.1692e-04 - val_Pressure_Output_loss: 2.0447e-04 - val_Scalars_Output_loss: 5.5817e-04 - val_Thrust_Output_loss: 6.6484e-05 - val_loss: 7.9881e-04 - learning_rate: 5.0000e-04
# Epoch 47/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8767e-04 - Scalars_Output_loss: 5.4484e-04 - Thrust_Output_loss: 5.6437e-05 - loss: 7.8901e-04 - val_Pressure_Output_loss: 1.9921e-04 - val_Scalars_Output_loss: 5.5323e-04 - val_Thrust_Output_loss: 5.6849e-05 - val_loss: 7.6871e-04 - learning_rate: 5.0000e-04
# Epoch 48/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.4297e-04 - Scalars_Output_loss: 5.5943e-04 - Thrust_Output_loss: 4.9388e-05 - loss: 7.5185e-04 - val_Pressure_Output_loss: 1.5953e-04 - val_Scalars_Output_loss: 5.3950e-04 - val_Thrust_Output_loss: 5.6385e-05 - val_loss: 7.2134e-04 - learning_rate: 5.0000e-04
# Epoch 49/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 1.7645e-04 - Scalars_Output_loss: 4.9994e-04 - Thrust_Output_loss: 5.8656e-05 - loss: 7.3518e-04 - val_Pressure_Output_loss: 1.7978e-04 - val_Scalars_Output_loss: 5.5564e-04 - val_Thrust_Output_loss: 8.3420e-05 - val_loss: 7.8586e-04 - learning_rate: 5.0000e-04
# Epoch 50/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7769e-04 - Scalars_Output_loss: 5.2227e-04 - Thrust_Output_loss: 7.5635e-05 - loss: 7.7545e-04 - val_Pressure_Output_loss: 3.9756e-04 - val_Scalars_Output_loss: 5.3494e-04 - val_Thrust_Output_loss: 1.6904e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 51/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.8101e-04 - Scalars_Output_loss: 5.6088e-04 - Thrust_Output_loss: 1.1073e-04 - loss: 9.5270e-04 - val_Pressure_Output_loss: 2.5633e-04 - val_Scalars_Output_loss: 5.3338e-04 - val_Thrust_Output_loss: 6.1317e-05 - val_loss: 8.0586e-04 - learning_rate: 5.0000e-04
# Epoch 52/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.0156e-04 - Scalars_Output_loss: 4.8600e-04 - Thrust_Output_loss: 6.5783e-05 - loss: 7.5338e-04 - val_Pressure_Output_loss: 3.3025e-04 - val_Scalars_Output_loss: 5.8611e-04 - val_Thrust_Output_loss: 7.6150e-05 - val_loss: 9.4682e-04 - learning_rate: 5.0000e-04
# Epoch 53/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.4301e-04 - Scalars_Output_loss: 5.7230e-04 - Thrust_Output_loss: 1.2936e-04 - loss: 0.0010 - val_Pressure_Output_loss: 1.7823e-04 - val_Scalars_Output_loss: 4.8482e-04 - val_Thrust_Output_loss: 5.5006e-05 - val_loss: 6.7551e-04 - learning_rate: 5.0000e-04
# Epoch 54/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Pressure_Output_loss: 3.0718e-04 - Scalars_Output_loss: 5.0429e-04 - Thrust_Output_loss: 9.0006e-05 - loss: 9.0148e-04
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.0680e-04 - Scalars_Output_loss: 5.0442e-04 - Thrust_Output_loss: 8.9866e-05 - loss: 9.0117e-04 - val_Pressure_Output_loss: 2.8050e-04 - val_Scalars_Output_loss: 5.1373e-04 - val_Thrust_Output_loss: 2.2446e-04 - val_loss: 9.5018e-04 - learning_rate: 5.0000e-04
# Epoch 55/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.6360e-04 - Scalars_Output_loss: 4.9343e-04 - Thrust_Output_loss: 8.6270e-05 - loss: 7.4342e-04 - val_Pressure_Output_loss: 1.2106e-04 - val_Scalars_Output_loss: 4.6891e-04 - val_Thrust_Output_loss: 4.8305e-05 - val_loss: 6.0498e-04 - learning_rate: 2.5000e-04
# Epoch 56/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 7.3300e-05 - Scalars_Output_loss: 4.6189e-04 - Thrust_Output_loss: 2.8742e-05 - loss: 5.6396e-04 - val_Pressure_Output_loss: 8.6530e-05 - val_Scalars_Output_loss: 4.6801e-04 - val_Thrust_Output_loss: 4.4672e-05 - val_loss: 5.5968e-04 - learning_rate: 2.5000e-04
# Epoch 57/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 7.3874e-05 - Scalars_Output_loss: 4.4617e-04 - Thrust_Output_loss: 2.7052e-05 - loss: 5.4702e-04 - val_Pressure_Output_loss: 1.4383e-04 - val_Scalars_Output_loss: 4.5696e-04 - val_Thrust_Output_loss: 5.4724e-05 - val_loss: 6.2231e-04 - learning_rate: 2.5000e-04
# Epoch 58/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 9.6776e-05 - Scalars_Output_loss: 4.7138e-04 - Thrust_Output_loss: 3.5450e-05 - loss: 6.0372e-04 - val_Pressure_Output_loss: 9.2808e-05 - val_Scalars_Output_loss: 4.6965e-04 - val_Thrust_Output_loss: 3.7864e-05 - val_loss: 5.6165e-04 - learning_rate: 2.5000e-04
# Epoch 59/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 9.0931e-05 - Scalars_Output_loss: 4.6001e-04 - Thrust_Output_loss: 3.0278e-05 - loss: 5.8120e-04 - val_Pressure_Output_loss: 9.4231e-05 - val_Scalars_Output_loss: 4.6273e-04 - val_Thrust_Output_loss: 4.1729e-05 - val_loss: 5.6223e-04 - learning_rate: 2.5000e-04
# Epoch 60/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 7.2058e-05 - Scalars_Output_loss: 4.6543e-04 - Thrust_Output_loss: 2.4946e-05 - loss: 5.6245e-04 - val_Pressure_Output_loss: 9.2904e-05 - val_Scalars_Output_loss: 5.0112e-04 - val_Thrust_Output_loss: 3.7134e-05 - val_loss: 5.9466e-04 - learning_rate: 2.5000e-04
# Epoch 61/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 7.1146e-05 - Scalars_Output_loss: 4.6442e-04 - Thrust_Output_loss: 2.7318e-05 - loss: 5.6300e-04 - val_Pressure_Output_loss: 1.1247e-04 - val_Scalars_Output_loss: 4.4349e-04 - val_Thrust_Output_loss: 2.5320e-05 - val_loss: 5.4975e-04 - learning_rate: 2.5000e-04
# Epoch 62/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 7.7305e-05 - Scalars_Output_loss: 4.5633e-04 - Thrust_Output_loss: 2.6632e-05 - loss: 5.6006e-04 - val_Pressure_Output_loss: 9.6094e-05 - val_Scalars_Output_loss: 5.0374e-04 - val_Thrust_Output_loss: 5.8397e-05 - val_loss: 6.2075e-04 - learning_rate: 2.5000e-04
# Epoch 63/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 8.8741e-05 - Scalars_Output_loss: 4.5938e-04 - Thrust_Output_loss: 3.3741e-05 - loss: 5.8200e-04 - val_Pressure_Output_loss: 9.5364e-05 - val_Scalars_Output_loss: 4.4094e-04 - val_Thrust_Output_loss: 2.7708e-05 - val_loss: 5.3288e-04 - learning_rate: 2.5000e-04
# Epoch 64/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 9.0693e-05 - Scalars_Output_loss: 4.3551e-04 - Thrust_Output_loss: 2.6143e-05 - loss: 5.5241e-04 - val_Pressure_Output_loss: 2.0577e-04 - val_Scalars_Output_loss: 4.9168e-04 - val_Thrust_Output_loss: 9.2814e-05 - val_loss: 7.2514e-04 - learning_rate: 2.5000e-04
# Epoch 65/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Pressure_Output_loss: 1.4382e-04 - Scalars_Output_loss: 4.4335e-04 - Thrust_Output_loss: 5.8237e-05 - loss: 6.4541e-04
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.4339e-04 - Scalars_Output_loss: 4.4331e-04 - Thrust_Output_loss: 5.7988e-05 - loss: 6.4482e-04 - val_Pressure_Output_loss: 8.3601e-05 - val_Scalars_Output_loss: 4.3323e-04 - val_Thrust_Output_loss: 2.1896e-05 - val_loss: 5.1018e-04 - learning_rate: 2.5000e-04
# Epoch 66/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.8526e-05 - Scalars_Output_loss: 4.3829e-04 - Thrust_Output_loss: 1.8830e-05 - loss: 5.1569e-04 - val_Pressure_Output_loss: 7.5713e-05 - val_Scalars_Output_loss: 4.4979e-04 - val_Thrust_Output_loss: 2.4057e-05 - val_loss: 5.1284e-04 - learning_rate: 1.2500e-04
# Epoch 67/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.7723e-05 - Scalars_Output_loss: 4.3728e-04 - Thrust_Output_loss: 1.8351e-05 - loss: 5.1348e-04 - val_Pressure_Output_loss: 1.1587e-04 - val_Scalars_Output_loss: 4.3335e-04 - val_Thrust_Output_loss: 2.1915e-05 - val_loss: 5.4094e-04 - learning_rate: 1.2500e-04
# Epoch 68/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.1173e-05 - Scalars_Output_loss: 4.1835e-04 - Thrust_Output_loss: 1.7096e-05 - loss: 4.9668e-04 - val_Pressure_Output_loss: 6.7571e-05 - val_Scalars_Output_loss: 4.3631e-04 - val_Thrust_Output_loss: 1.9290e-05 - val_loss: 4.8998e-04 - learning_rate: 1.2500e-04
# Epoch 69/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.3099e-05 - Scalars_Output_loss: 4.3290e-04 - Thrust_Output_loss: 1.6136e-05 - loss: 5.0216e-04 - val_Pressure_Output_loss: 7.3327e-05 - val_Scalars_Output_loss: 4.4840e-04 - val_Thrust_Output_loss: 2.1938e-05 - val_loss: 5.1187e-04 - learning_rate: 1.2500e-04
# Epoch 70/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.9266e-05 - Scalars_Output_loss: 4.4062e-04 - Thrust_Output_loss: 2.3067e-05 - loss: 5.3304e-04 - val_Pressure_Output_loss: 9.1931e-05 - val_Scalars_Output_loss: 4.3472e-04 - val_Thrust_Output_loss: 2.4268e-05 - val_loss: 5.1910e-04 - learning_rate: 1.2500e-04
# Epoch 71/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.0593e-05 - Scalars_Output_loss: 4.0080e-04 - Thrust_Output_loss: 2.0779e-05 - loss: 4.8220e-04 - val_Pressure_Output_loss: 9.3375e-05 - val_Scalars_Output_loss: 4.3041e-04 - val_Thrust_Output_loss: 2.4491e-05 - val_loss: 5.1927e-04 - learning_rate: 1.2500e-04
# Epoch 72/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.7970e-05 - Scalars_Output_loss: 4.3060e-04 - Thrust_Output_loss: 1.7250e-05 - loss: 5.0587e-04 - val_Pressure_Output_loss: 9.0040e-05 - val_Scalars_Output_loss: 4.2540e-04 - val_Thrust_Output_loss: 2.2702e-05 - val_loss: 5.0860e-04 - learning_rate: 1.2500e-04
# Epoch 73/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.8933e-05 - Scalars_Output_loss: 4.3848e-04 - Thrust_Output_loss: 1.7990e-05 - loss: 5.1540e-04 - val_Pressure_Output_loss: 9.1640e-05 - val_Scalars_Output_loss: 4.2387e-04 - val_Thrust_Output_loss: 2.1241e-05 - val_loss: 4.9810e-04 - learning_rate: 1.2500e-04
# Epoch 74/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 7.1383e-05 - Scalars_Output_loss: 4.0069e-04 - Thrust_Output_loss: 1.8887e-05 - loss: 4.9101e-04 - val_Pressure_Output_loss: 8.6309e-05 - val_Scalars_Output_loss: 4.2993e-04 - val_Thrust_Output_loss: 2.0433e-05 - val_loss: 5.0492e-04 - learning_rate: 1.2500e-04
# Epoch 75/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.0024e-05 - Scalars_Output_loss: 4.1163e-04 - Thrust_Output_loss: 1.9169e-05 - loss: 4.9088e-04 - val_Pressure_Output_loss: 7.5870e-05 - val_Scalars_Output_loss: 4.3823e-04 - val_Thrust_Output_loss: 2.3820e-05 - val_loss: 4.9876e-04 - learning_rate: 1.2500e-04
# Epoch 76/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.6618e-05 - Scalars_Output_loss: 4.2094e-04 - Thrust_Output_loss: 1.9882e-05 - loss: 4.9724e-04 - val_Pressure_Output_loss: 8.7362e-05 - val_Scalars_Output_loss: 4.1945e-04 - val_Thrust_Output_loss: 2.2773e-05 - val_loss: 4.9667e-04 - learning_rate: 1.2500e-04
# Epoch 77/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 6.1950e-05 - Scalars_Output_loss: 4.0406e-04 - Thrust_Output_loss: 1.8770e-05 - loss: 4.8487e-04 - val_Pressure_Output_loss: 8.4259e-05 - val_Scalars_Output_loss: 4.2756e-04 - val_Thrust_Output_loss: 2.7048e-05 - val_loss: 5.0397e-04 - learning_rate: 1.2500e-04
# Epoch 78/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - Pressure_Output_loss: 6.0264e-05 - Scalars_Output_loss: 4.2915e-04 - Thrust_Output_loss: 2.0061e-05 - loss: 5.0948e-04
# Epoch 78: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.0247e-05 - Scalars_Output_loss: 4.2892e-04 - Thrust_Output_loss: 2.0052e-05 - loss: 5.0915e-04 - val_Pressure_Output_loss: 8.3562e-05 - val_Scalars_Output_loss: 4.1816e-04 - val_Thrust_Output_loss: 2.1099e-05 - val_loss: 4.9427e-04 - learning_rate: 1.2500e-04
# Epoch 79/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 5.0525e-05 - Scalars_Output_loss: 4.1561e-04 - Thrust_Output_loss: 1.5230e-05 - loss: 4.8117e-04 - val_Pressure_Output_loss: 5.9358e-05 - val_Scalars_Output_loss: 4.2462e-04 - val_Thrust_Output_loss: 1.8636e-05 - val_loss: 4.7088e-04 - learning_rate: 6.2500e-05
# Epoch 80/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.6211e-05 - Scalars_Output_loss: 3.9711e-04 - Thrust_Output_loss: 1.4790e-05 - loss: 4.5817e-04 - val_Pressure_Output_loss: 6.6887e-05 - val_Scalars_Output_loss: 4.2897e-04 - val_Thrust_Output_loss: 2.0161e-05 - val_loss: 4.7978e-04 - learning_rate: 6.2500e-05
# Epoch 81/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 4.2941e-05 - Scalars_Output_loss: 3.8674e-04 - Thrust_Output_loss: 1.4535e-05 - loss: 4.4428e-04 - val_Pressure_Output_loss: 6.5440e-05 - val_Scalars_Output_loss: 4.1011e-04 - val_Thrust_Output_loss: 2.0953e-05 - val_loss: 4.6554e-04 - learning_rate: 6.2500e-05
# Epoch 82/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.2762e-05 - Scalars_Output_loss: 4.1097e-04 - Thrust_Output_loss: 1.3602e-05 - loss: 4.6744e-04 - val_Pressure_Output_loss: 6.4571e-05 - val_Scalars_Output_loss: 4.2474e-04 - val_Thrust_Output_loss: 1.9113e-05 - val_loss: 4.7513e-04 - learning_rate: 6.2500e-05
# Epoch 83/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.3122e-05 - Scalars_Output_loss: 3.8130e-04 - Thrust_Output_loss: 1.3634e-05 - loss: 4.3817e-04 - val_Pressure_Output_loss: 6.3599e-05 - val_Scalars_Output_loss: 4.1204e-04 - val_Thrust_Output_loss: 1.8282e-05 - val_loss: 4.6465e-04 - learning_rate: 6.2500e-05
# Epoch 84/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.5121e-05 - Scalars_Output_loss: 3.8278e-04 - Thrust_Output_loss: 1.3581e-05 - loss: 4.4144e-04 - val_Pressure_Output_loss: 6.8172e-05 - val_Scalars_Output_loss: 4.1525e-04 - val_Thrust_Output_loss: 1.7525e-05 - val_loss: 4.7196e-04 - learning_rate: 6.2500e-05
# Epoch 85/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.1667e-05 - Scalars_Output_loss: 4.0986e-04 - Thrust_Output_loss: 1.2193e-05 - loss: 4.6364e-04 - val_Pressure_Output_loss: 6.7751e-05 - val_Scalars_Output_loss: 4.0780e-04 - val_Thrust_Output_loss: 1.8216e-05 - val_loss: 4.6228e-04 - learning_rate: 6.2500e-05
# Epoch 86/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 6.0849e-05 - Scalars_Output_loss: 3.6367e-04 - Thrust_Output_loss: 1.8383e-05 - loss: 4.4287e-04 - val_Pressure_Output_loss: 6.1750e-05 - val_Scalars_Output_loss: 4.0602e-04 - val_Thrust_Output_loss: 2.1189e-05 - val_loss: 4.6045e-04 - learning_rate: 6.2500e-05
# Epoch 87/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.5045e-05 - Scalars_Output_loss: 4.1114e-04 - Thrust_Output_loss: 1.3424e-05 - loss: 4.6971e-04 - val_Pressure_Output_loss: 6.6136e-05 - val_Scalars_Output_loss: 4.1908e-04 - val_Thrust_Output_loss: 2.2495e-05 - val_loss: 4.7287e-04 - learning_rate: 6.2500e-05
# Epoch 88/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Pressure_Output_loss: 4.3098e-05 - Scalars_Output_loss: 4.3242e-04 - Thrust_Output_loss: 1.4233e-05 - loss: 4.8975e-04
# Epoch 88: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.3162e-05 - Scalars_Output_loss: 4.3174e-04 - Thrust_Output_loss: 1.4223e-05 - loss: 4.8904e-04 - val_Pressure_Output_loss: 6.2363e-05 - val_Scalars_Output_loss: 4.1524e-04 - val_Thrust_Output_loss: 2.2853e-05 - val_loss: 4.7073e-04 - learning_rate: 6.2500e-05
# Epoch 89/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.3660e-05 - Scalars_Output_loss: 4.1484e-04 - Thrust_Output_loss: 1.4142e-05 - loss: 4.7267e-04 - val_Pressure_Output_loss: 6.2501e-05 - val_Scalars_Output_loss: 4.0892e-04 - val_Thrust_Output_loss: 1.6407e-05 - val_loss: 4.5710e-04 - learning_rate: 3.1250e-05
# Epoch 90/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 4.2340e-05 - Scalars_Output_loss: 3.7795e-04 - Thrust_Output_loss: 1.2549e-05 - loss: 4.3286e-04 - val_Pressure_Output_loss: 6.2105e-05 - val_Scalars_Output_loss: 4.0043e-04 - val_Thrust_Output_loss: 1.8035e-05 - val_loss: 4.4955e-04 - learning_rate: 3.1250e-05
# Epoch 91/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 4.2721e-05 - Scalars_Output_loss: 4.0532e-04 - Thrust_Output_loss: 1.2664e-05 - loss: 4.6065e-04 - val_Pressure_Output_loss: 5.5917e-05 - val_Scalars_Output_loss: 4.0737e-04 - val_Thrust_Output_loss: 1.6074e-05 - val_loss: 4.5079e-04 - learning_rate: 3.1250e-05
# Epoch 92/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.7885e-05 - Scalars_Output_loss: 3.8417e-04 - Thrust_Output_loss: 1.1571e-05 - loss: 4.3350e-04 - val_Pressure_Output_loss: 5.7453e-05 - val_Scalars_Output_loss: 4.0216e-04 - val_Thrust_Output_loss: 1.6912e-05 - val_loss: 4.4729e-04 - learning_rate: 3.1250e-05
# Epoch 93/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.6579e-05 - Scalars_Output_loss: 4.1343e-04 - Thrust_Output_loss: 1.1111e-05 - loss: 4.6099e-04 - val_Pressure_Output_loss: 5.9509e-05 - val_Scalars_Output_loss: 4.0923e-04 - val_Thrust_Output_loss: 1.7240e-05 - val_loss: 4.5688e-04 - learning_rate: 3.1250e-05
# Epoch 94/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.8232e-05 - Scalars_Output_loss: 4.2707e-04 - Thrust_Output_loss: 1.1000e-05 - loss: 4.7642e-04 - val_Pressure_Output_loss: 5.8010e-05 - val_Scalars_Output_loss: 4.0254e-04 - val_Thrust_Output_loss: 1.6208e-05 - val_loss: 4.4768e-04 - learning_rate: 3.1250e-05
# Epoch 95/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.6962e-05 - Scalars_Output_loss: 3.9115e-04 - Thrust_Output_loss: 1.1805e-05 - loss: 4.3983e-04 - val_Pressure_Output_loss: 5.8306e-05 - val_Scalars_Output_loss: 3.9978e-04 - val_Thrust_Output_loss: 1.5880e-05 - val_loss: 4.4580e-04 - learning_rate: 3.1250e-05
# Epoch 96/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.7757e-05 - Scalars_Output_loss: 4.0007e-04 - Thrust_Output_loss: 1.1348e-05 - loss: 4.4927e-04 - val_Pressure_Output_loss: 6.0492e-05 - val_Scalars_Output_loss: 4.0874e-04 - val_Thrust_Output_loss: 1.6803e-05 - val_loss: 4.5651e-04 - learning_rate: 3.1250e-05
# Epoch 97/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.9662e-05 - Scalars_Output_loss: 3.7369e-04 - Thrust_Output_loss: 1.1497e-05 - loss: 4.2492e-04 - val_Pressure_Output_loss: 5.6962e-05 - val_Scalars_Output_loss: 4.0448e-04 - val_Thrust_Output_loss: 1.6519e-05 - val_loss: 4.4968e-04 - learning_rate: 3.1250e-05
# Epoch 98/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Pressure_Output_loss: 3.6994e-05 - Scalars_Output_loss: 3.9651e-04 - Thrust_Output_loss: 1.1111e-05 - loss: 4.4461e-04
# Epoch 98: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.7015e-05 - Scalars_Output_loss: 3.9640e-04 - Thrust_Output_loss: 1.1123e-05 - loss: 4.4462e-04 - val_Pressure_Output_loss: 5.4838e-05 - val_Scalars_Output_loss: 4.0121e-04 - val_Thrust_Output_loss: 1.9205e-05 - val_loss: 4.4521e-04 - learning_rate: 3.1250e-05
# Epoch 99/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5886e-05 - Scalars_Output_loss: 4.0618e-04 - Thrust_Output_loss: 1.0654e-05 - loss: 4.5282e-04 - val_Pressure_Output_loss: 5.6466e-05 - val_Scalars_Output_loss: 3.9642e-04 - val_Thrust_Output_loss: 1.5895e-05 - val_loss: 4.3806e-04 - learning_rate: 1.5625e-05
# Epoch 100/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.4249e-05 - Scalars_Output_loss: 3.6663e-04 - Thrust_Output_loss: 1.0251e-05 - loss: 4.1118e-04 - val_Pressure_Output_loss: 5.6376e-05 - val_Scalars_Output_loss: 3.9605e-04 - val_Thrust_Output_loss: 1.5872e-05 - val_loss: 4.3993e-04 - learning_rate: 1.5625e-05
# Epoch 101/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5363e-05 - Scalars_Output_loss: 3.8726e-04 - Thrust_Output_loss: 1.0588e-05 - loss: 4.3321e-04 - val_Pressure_Output_loss: 5.5028e-05 - val_Scalars_Output_loss: 4.0333e-04 - val_Thrust_Output_loss: 1.6184e-05 - val_loss: 4.4281e-04 - learning_rate: 1.5625e-05
# Epoch 102/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.6755e-05 - Scalars_Output_loss: 3.7673e-04 - Thrust_Output_loss: 1.0693e-05 - loss: 4.2408e-04 - val_Pressure_Output_loss: 5.4290e-05 - val_Scalars_Output_loss: 4.0679e-04 - val_Thrust_Output_loss: 1.5644e-05 - val_loss: 4.4641e-04 - learning_rate: 1.5625e-05
# Epoch 103/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.4969e-05 - Scalars_Output_loss: 4.0763e-04 - Thrust_Output_loss: 9.9579e-06 - loss: 4.5266e-04 - val_Pressure_Output_loss: 5.4410e-05 - val_Scalars_Output_loss: 4.0144e-04 - val_Thrust_Output_loss: 1.5707e-05 - val_loss: 4.4241e-04 - learning_rate: 1.5625e-05
# Epoch 104/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5189e-05 - Scalars_Output_loss: 3.5638e-04 - Thrust_Output_loss: 1.0687e-05 - loss: 4.0231e-04 - val_Pressure_Output_loss: 5.5071e-05 - val_Scalars_Output_loss: 4.0655e-04 - val_Thrust_Output_loss: 1.5736e-05 - val_loss: 4.4938e-04 - learning_rate: 1.5625e-05
# Epoch 105/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.6074e-05 - Scalars_Output_loss: 3.9231e-04 - Thrust_Output_loss: 1.0586e-05 - loss: 4.3863e-04 - val_Pressure_Output_loss: 5.7355e-05 - val_Scalars_Output_loss: 4.0157e-04 - val_Thrust_Output_loss: 1.7483e-05 - val_loss: 4.4836e-04 - learning_rate: 1.5625e-05
# Epoch 106/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.6125e-05 - Scalars_Output_loss: 4.0297e-04 - Thrust_Output_loss: 1.0698e-05 - loss: 4.4982e-04 - val_Pressure_Output_loss: 5.6816e-05 - val_Scalars_Output_loss: 3.9862e-04 - val_Thrust_Output_loss: 1.7072e-05 - val_loss: 4.4267e-04 - learning_rate: 1.5625e-05
# Epoch 107/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.2126e-05 - Scalars_Output_loss: 3.8511e-04 - Thrust_Output_loss: 9.8484e-06 - loss: 4.2719e-04 - val_Pressure_Output_loss: 5.5759e-05 - val_Scalars_Output_loss: 3.9862e-04 - val_Thrust_Output_loss: 1.6351e-05 - val_loss: 4.4244e-04 - learning_rate: 1.5625e-05
# Epoch 108/400
# 69/70 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Pressure_Output_loss: 3.5665e-05 - Scalars_Output_loss: 3.9489e-04 - Thrust_Output_loss: 1.0677e-05 - loss: 4.4123e-04
# Epoch 108: ReduceLROnPlateau reducing learning rate to 1e-05.
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5653e-05 - Scalars_Output_loss: 3.9482e-04 - Thrust_Output_loss: 1.0672e-05 - loss: 4.4109e-04 - val_Pressure_Output_loss: 5.4399e-05 - val_Scalars_Output_loss: 4.0298e-04 - val_Thrust_Output_loss: 1.5867e-05 - val_loss: 4.4289e-04 - learning_rate: 1.5625e-05
# Epoch 109/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.4283e-05 - Scalars_Output_loss: 4.1158e-04 - Thrust_Output_loss: 1.0601e-05 - loss: 4.5653e-04 - val_Pressure_Output_loss: 5.3697e-05 - val_Scalars_Output_loss: 3.9718e-04 - val_Thrust_Output_loss: 1.5663e-05 - val_loss: 4.3721e-04 - learning_rate: 1.0000e-05
# Epoch 110/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.2639e-05 - Scalars_Output_loss: 3.9940e-04 - Thrust_Output_loss: 9.6434e-06 - loss: 4.4160e-04 - val_Pressure_Output_loss: 5.3116e-05 - val_Scalars_Output_loss: 3.9755e-04 - val_Thrust_Output_loss: 1.5206e-05 - val_loss: 4.3731e-04 - learning_rate: 1.0000e-05
# Epoch 111/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.5884e-05 - Scalars_Output_loss: 4.1344e-04 - Thrust_Output_loss: 1.0519e-05 - loss: 4.5993e-04 - val_Pressure_Output_loss: 5.3566e-05 - val_Scalars_Output_loss: 3.9806e-04 - val_Thrust_Output_loss: 1.5349e-05 - val_loss: 4.3677e-04 - learning_rate: 1.0000e-05
# Epoch 112/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.3965e-05 - Scalars_Output_loss: 3.5644e-04 - Thrust_Output_loss: 9.8733e-06 - loss: 3.9984e-04 - val_Pressure_Output_loss: 5.2963e-05 - val_Scalars_Output_loss: 4.0421e-04 - val_Thrust_Output_loss: 1.5508e-05 - val_loss: 4.4319e-04 - learning_rate: 1.0000e-05
# Epoch 113/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5096e-05 - Scalars_Output_loss: 4.0660e-04 - Thrust_Output_loss: 9.9311e-06 - loss: 4.5173e-04 - val_Pressure_Output_loss: 5.3594e-05 - val_Scalars_Output_loss: 3.9900e-04 - val_Thrust_Output_loss: 1.5541e-05 - val_loss: 4.3895e-04 - learning_rate: 1.0000e-05
# Epoch 114/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.4919e-05 - Scalars_Output_loss: 3.9799e-04 - Thrust_Output_loss: 1.0116e-05 - loss: 4.4311e-04 - val_Pressure_Output_loss: 5.5459e-05 - val_Scalars_Output_loss: 3.9810e-04 - val_Thrust_Output_loss: 1.6527e-05 - val_loss: 4.3880e-04 - learning_rate: 1.0000e-05
# Epoch 115/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.3271e-05 - Scalars_Output_loss: 4.0175e-04 - Thrust_Output_loss: 1.0105e-05 - loss: 4.4513e-04 - val_Pressure_Output_loss: 5.7344e-05 - val_Scalars_Output_loss: 3.9989e-04 - val_Thrust_Output_loss: 1.6678e-05 - val_loss: 4.4357e-04 - learning_rate: 1.0000e-05
# Epoch 116/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.4947e-05 - Scalars_Output_loss: 3.7328e-04 - Thrust_Output_loss: 1.0718e-05 - loss: 4.1904e-04 - val_Pressure_Output_loss: 5.4540e-05 - val_Scalars_Output_loss: 4.0035e-04 - val_Thrust_Output_loss: 1.5503e-05 - val_loss: 4.4219e-04 - learning_rate: 1.0000e-05
# Epoch 117/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.2697e-05 - Scalars_Output_loss: 3.9228e-04 - Thrust_Output_loss: 9.9490e-06 - loss: 4.3495e-04 - val_Pressure_Output_loss: 5.4151e-05 - val_Scalars_Output_loss: 3.9515e-04 - val_Thrust_Output_loss: 1.5138e-05 - val_loss: 4.3684e-04 - learning_rate: 1.0000e-05
# Epoch 118/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.3408e-05 - Scalars_Output_loss: 4.1886e-04 - Thrust_Output_loss: 9.5090e-06 - loss: 4.6170e-04 - val_Pressure_Output_loss: 5.3533e-05 - val_Scalars_Output_loss: 3.9912e-04 - val_Thrust_Output_loss: 1.4657e-05 - val_loss: 4.3920e-04 - learning_rate: 1.0000e-05
# Epoch 119/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.1656e-05 - Scalars_Output_loss: 3.7862e-04 - Thrust_Output_loss: 9.5139e-06 - loss: 4.1947e-04 - val_Pressure_Output_loss: 5.2561e-05 - val_Scalars_Output_loss: 3.9509e-04 - val_Thrust_Output_loss: 1.5081e-05 - val_loss: 4.3514e-04 - learning_rate: 1.0000e-05
# Epoch 120/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.3429e-05 - Scalars_Output_loss: 3.9247e-04 - Thrust_Output_loss: 1.0246e-05 - loss: 4.3623e-04 - val_Pressure_Output_loss: 5.3750e-05 - val_Scalars_Output_loss: 3.9523e-04 - val_Thrust_Output_loss: 1.5420e-05 - val_loss: 4.3661e-04 - learning_rate: 1.0000e-05
# Epoch 121/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5646e-05 - Scalars_Output_loss: 3.9040e-04 - Thrust_Output_loss: 1.0727e-05 - loss: 4.3684e-04 - val_Pressure_Output_loss: 5.4060e-05 - val_Scalars_Output_loss: 3.9744e-04 - val_Thrust_Output_loss: 1.5796e-05 - val_loss: 4.3752e-04 - learning_rate: 1.0000e-05
# Epoch 122/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.2581e-05 - Scalars_Output_loss: 3.7083e-04 - Thrust_Output_loss: 1.0070e-05 - loss: 4.1355e-04 - val_Pressure_Output_loss: 5.3210e-05 - val_Scalars_Output_loss: 3.9287e-04 - val_Thrust_Output_loss: 1.4882e-05 - val_loss: 4.3344e-04 - learning_rate: 1.0000e-05
# Epoch 123/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.4641e-05 - Scalars_Output_loss: 3.8427e-04 - Thrust_Output_loss: 1.0590e-05 - loss: 4.2958e-04 - val_Pressure_Output_loss: 5.2453e-05 - val_Scalars_Output_loss: 3.9714e-04 - val_Thrust_Output_loss: 1.4777e-05 - val_loss: 4.3443e-04 - learning_rate: 1.0000e-05
# Epoch 124/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.5547e-05 - Scalars_Output_loss: 3.7679e-04 - Thrust_Output_loss: 1.0180e-05 - loss: 4.2256e-04 - val_Pressure_Output_loss: 5.2204e-05 - val_Scalars_Output_loss: 3.9796e-04 - val_Thrust_Output_loss: 1.5002e-05 - val_loss: 4.3584e-04 - learning_rate: 1.0000e-05
# Epoch 125/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.4058e-05 - Scalars_Output_loss: 3.9307e-04 - Thrust_Output_loss: 1.0404e-05 - loss: 4.3758e-04 - val_Pressure_Output_loss: 5.5004e-05 - val_Scalars_Output_loss: 3.9937e-04 - val_Thrust_Output_loss: 1.5919e-05 - val_loss: 4.4221e-04 - learning_rate: 1.0000e-05
# Epoch 126/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.3099e-05 - Scalars_Output_loss: 4.0027e-04 - Thrust_Output_loss: 1.0200e-05 - loss: 4.4364e-04 - val_Pressure_Output_loss: 5.3724e-05 - val_Scalars_Output_loss: 3.9735e-04 - val_Thrust_Output_loss: 1.5396e-05 - val_loss: 4.3800e-04 - learning_rate: 1.0000e-05
# Epoch 127/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.4023e-05 - Scalars_Output_loss: 3.5359e-04 - Thrust_Output_loss: 1.0431e-05 - loss: 3.9815e-04 - val_Pressure_Output_loss: 5.2997e-05 - val_Scalars_Output_loss: 3.9690e-04 - val_Thrust_Output_loss: 1.5284e-05 - val_loss: 4.3680e-04 - learning_rate: 1.0000e-05
# Epoch 128/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.2417e-05 - Scalars_Output_loss: 3.6808e-04 - Thrust_Output_loss: 9.7304e-06 - loss: 4.1033e-04 - val_Pressure_Output_loss: 5.2334e-05 - val_Scalars_Output_loss: 3.9930e-04 - val_Thrust_Output_loss: 1.5250e-05 - val_loss: 4.3818e-04 - learning_rate: 1.0000e-05
# Epoch 129/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.2923e-05 - Scalars_Output_loss: 3.7391e-04 - Thrust_Output_loss: 9.8602e-06 - loss: 4.1676e-04 - val_Pressure_Output_loss: 5.2014e-05 - val_Scalars_Output_loss: 3.9467e-04 - val_Thrust_Output_loss: 1.5108e-05 - val_loss: 4.3321e-04 - learning_rate: 1.0000e-05
# Epoch 130/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.4017e-05 - Scalars_Output_loss: 3.8830e-04 - Thrust_Output_loss: 9.8237e-06 - loss: 4.3217e-04 - val_Pressure_Output_loss: 5.1723e-05 - val_Scalars_Output_loss: 4.0230e-04 - val_Thrust_Output_loss: 1.4764e-05 - val_loss: 4.4019e-04 - learning_rate: 1.0000e-05
# Epoch 131/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.2692e-05 - Scalars_Output_loss: 3.6324e-04 - Thrust_Output_loss: 1.0251e-05 - loss: 4.0609e-04 - val_Pressure_Output_loss: 5.2486e-05 - val_Scalars_Output_loss: 3.9269e-04 - val_Thrust_Output_loss: 1.4691e-05 - val_loss: 4.3190e-04 - learning_rate: 1.0000e-05
# Epoch 132/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.3120e-05 - Scalars_Output_loss: 3.7192e-04 - Thrust_Output_loss: 9.4587e-06 - loss: 4.1427e-04 - val_Pressure_Output_loss: 5.3067e-05 - val_Scalars_Output_loss: 3.9432e-04 - val_Thrust_Output_loss: 1.5086e-05 - val_loss: 4.3332e-04 - learning_rate: 1.0000e-05
# Epoch 133/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.1547e-05 - Scalars_Output_loss: 3.6673e-04 - Thrust_Output_loss: 9.7351e-06 - loss: 4.0800e-04 - val_Pressure_Output_loss: 5.3893e-05 - val_Scalars_Output_loss: 3.9893e-04 - val_Thrust_Output_loss: 1.5572e-05 - val_loss: 4.3958e-04 - learning_rate: 1.0000e-05
# Epoch 134/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.5976e-05 - Scalars_Output_loss: 3.6371e-04 - Thrust_Output_loss: 1.0697e-05 - loss: 4.1040e-04 - val_Pressure_Output_loss: 5.1301e-05 - val_Scalars_Output_loss: 4.0065e-04 - val_Thrust_Output_loss: 1.5457e-05 - val_loss: 4.3836e-04 - learning_rate: 1.0000e-05
# Epoch 135/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 3.2404e-05 - Scalars_Output_loss: 3.9289e-04 - Thrust_Output_loss: 9.1697e-06 - loss: 4.3457e-04 - val_Pressure_Output_loss: 5.2442e-05 - val_Scalars_Output_loss: 3.9573e-04 - val_Thrust_Output_loss: 1.5582e-05 - val_loss: 4.3616e-04 - learning_rate: 1.0000e-05
# Epoch 136/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.4853e-05 - Scalars_Output_loss: 3.7345e-04 - Thrust_Output_loss: 1.0627e-05 - loss: 4.1894e-04 - val_Pressure_Output_loss: 5.1080e-05 - val_Scalars_Output_loss: 3.9681e-04 - val_Thrust_Output_loss: 1.4740e-05 - val_loss: 4.3460e-04 - learning_rate: 1.0000e-05
# Epoch 137/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.2623e-05 - Scalars_Output_loss: 3.8889e-04 - Thrust_Output_loss: 9.8241e-06 - loss: 4.3140e-04 - val_Pressure_Output_loss: 5.0799e-05 - val_Scalars_Output_loss: 3.9200e-04 - val_Thrust_Output_loss: 1.5155e-05 - val_loss: 4.2897e-04 - learning_rate: 1.0000e-05
# Epoch 138/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 3.2171e-05 - Scalars_Output_loss: 3.7793e-04 - Thrust_Output_loss: 9.4366e-06 - loss: 4.1954e-04 - val_Pressure_Output_loss: 5.2876e-05 - val_Scalars_Output_loss: 3.9366e-04 - val_Thrust_Output_loss: 1.5216e-05 - val_loss: 4.3426e-04 - learning_rate: 1.0000e-05
# Epoch 139/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 3.1542e-05 - Scalars_Output_loss: 3.7277e-04 - Thrust_Output_loss: 9.3649e-06 - loss: 4.1359e-04 - val_Pressure_Output_loss: 5.1196e-05 - val_Scalars_Output_loss: 3.9748e-04 - val_Thrust_Output_loss: 1.4775e-05 - val_loss: 4.3208e-04 - learning_rate: 1.0000e-05
# ...
# Epoch 355/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8893e-05 - Scalars_Output_loss: 3.3908e-04 - Thrust_Output_loss: 5.6332e-06 - loss: 3.6356e-04 - val_Pressure_Output_loss: 3.1443e-05 - val_Scalars_Output_loss: 3.5943e-04 - val_Thrust_Output_loss: 1.0247e-05 - val_loss: 3.7908e-04 - learning_rate: 1.0000e-05
# Epoch 356/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.9903e-05 - Scalars_Output_loss: 3.6460e-04 - Thrust_Output_loss: 6.9999e-06 - loss: 3.9159e-04 - val_Pressure_Output_loss: 3.7338e-05 - val_Scalars_Output_loss: 3.5993e-04 - val_Thrust_Output_loss: 1.0073e-05 - val_loss: 3.8503e-04 - learning_rate: 1.0000e-05
# Epoch 357/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.9039e-05 - Scalars_Output_loss: 3.3717e-04 - Thrust_Output_loss: 5.8678e-06 - loss: 3.6184e-04 - val_Pressure_Output_loss: 3.1478e-05 - val_Scalars_Output_loss: 3.6648e-04 - val_Thrust_Output_loss: 9.5680e-06 - val_loss: 3.8565e-04 - learning_rate: 1.0000e-05
# Epoch 358/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.0021e-05 - Scalars_Output_loss: 3.3201e-04 - Thrust_Output_loss: 6.5318e-06 - loss: 3.5861e-04 - val_Pressure_Output_loss: 3.2514e-05 - val_Scalars_Output_loss: 3.5643e-04 - val_Thrust_Output_loss: 1.0279e-05 - val_loss: 3.7809e-04 - learning_rate: 1.0000e-05
# Epoch 359/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7209e-05 - Scalars_Output_loss: 3.3329e-04 - Thrust_Output_loss: 5.6607e-06 - loss: 3.5595e-04 - val_Pressure_Output_loss: 3.0723e-05 - val_Scalars_Output_loss: 3.6470e-04 - val_Thrust_Output_loss: 9.3130e-06 - val_loss: 3.8248e-04 - learning_rate: 1.0000e-05
# Epoch 360/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8150e-05 - Scalars_Output_loss: 3.4075e-04 - Thrust_Output_loss: 5.8326e-06 - loss: 3.6469e-04 - val_Pressure_Output_loss: 3.1757e-05 - val_Scalars_Output_loss: 3.5928e-04 - val_Thrust_Output_loss: 9.9110e-06 - val_loss: 3.7877e-04 - learning_rate: 1.0000e-05
# Epoch 361/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 2.0193e-05 - Scalars_Output_loss: 3.2261e-04 - Thrust_Output_loss: 6.2938e-06 - loss: 3.4919e-04 - val_Pressure_Output_loss: 2.9900e-05 - val_Scalars_Output_loss: 3.6172e-04 - val_Thrust_Output_loss: 9.4374e-06 - val_loss: 3.7908e-04 - learning_rate: 1.0000e-05
# Epoch 362/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7585e-05 - Scalars_Output_loss: 3.3640e-04 - Thrust_Output_loss: 5.8492e-06 - loss: 3.5992e-04 - val_Pressure_Output_loss: 3.0811e-05 - val_Scalars_Output_loss: 3.6285e-04 - val_Thrust_Output_loss: 9.4319e-06 - val_loss: 3.8154e-04 - learning_rate: 1.0000e-05
# Epoch 363/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.9981e-05 - Scalars_Output_loss: 3.3016e-04 - Thrust_Output_loss: 6.1965e-06 - loss: 3.5640e-04 - val_Pressure_Output_loss: 3.2275e-05 - val_Scalars_Output_loss: 3.5870e-04 - val_Thrust_Output_loss: 9.6270e-06 - val_loss: 3.7859e-04 - learning_rate: 1.0000e-05
# Epoch 364/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.9979e-05 - Scalars_Output_loss: 3.7852e-04 - Thrust_Output_loss: 6.1109e-06 - loss: 4.0464e-04 - val_Pressure_Output_loss: 3.3338e-05 - val_Scalars_Output_loss: 3.6243e-04 - val_Thrust_Output_loss: 9.3761e-06 - val_loss: 3.8362e-04 - learning_rate: 1.0000e-05
# Epoch 365/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.3733e-05 - Scalars_Output_loss: 3.3252e-04 - Thrust_Output_loss: 7.2882e-06 - loss: 3.6343e-04 - val_Pressure_Output_loss: 3.0694e-05 - val_Scalars_Output_loss: 3.6531e-04 - val_Thrust_Output_loss: 9.8881e-06 - val_loss: 3.8368e-04 - learning_rate: 1.0000e-05
# Epoch 366/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.9108e-05 - Scalars_Output_loss: 3.2683e-04 - Thrust_Output_loss: 6.2723e-06 - loss: 3.5221e-04 - val_Pressure_Output_loss: 3.2417e-05 - val_Scalars_Output_loss: 3.6121e-04 - val_Thrust_Output_loss: 9.5409e-06 - val_loss: 3.8105e-04 - learning_rate: 1.0000e-05
# Epoch 367/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - Pressure_Output_loss: 1.9230e-05 - Scalars_Output_loss: 3.6420e-04 - Thrust_Output_loss: 5.8202e-06 - loss: 3.8934e-04 - val_Pressure_Output_loss: 2.9541e-05 - val_Scalars_Output_loss: 3.5953e-04 - val_Thrust_Output_loss: 9.6123e-06 - val_loss: 3.7673e-04 - learning_rate: 1.0000e-05
# Epoch 368/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7912e-05 - Scalars_Output_loss: 3.1577e-04 - Thrust_Output_loss: 5.9049e-06 - loss: 3.3963e-04 - val_Pressure_Output_loss: 3.0069e-05 - val_Scalars_Output_loss: 3.5863e-04 - val_Thrust_Output_loss: 9.3243e-06 - val_loss: 3.7646e-04 - learning_rate: 1.0000e-05
# Epoch 369/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7892e-05 - Scalars_Output_loss: 3.4440e-04 - Thrust_Output_loss: 5.7128e-06 - loss: 3.6805e-04 - val_Pressure_Output_loss: 2.9761e-05 - val_Scalars_Output_loss: 3.6307e-04 - val_Thrust_Output_loss: 8.9542e-06 - val_loss: 3.8050e-04 - learning_rate: 1.0000e-05
# Epoch 370/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7271e-05 - Scalars_Output_loss: 3.4200e-04 - Thrust_Output_loss: 5.7550e-06 - loss: 3.6458e-04 - val_Pressure_Output_loss: 3.8429e-05 - val_Scalars_Output_loss: 3.5643e-04 - val_Thrust_Output_loss: 1.0986e-05 - val_loss: 3.8290e-04 - learning_rate: 1.0000e-05
# Epoch 371/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.9430e-05 - Scalars_Output_loss: 3.2590e-04 - Thrust_Output_loss: 6.5046e-06 - loss: 3.5187e-04 - val_Pressure_Output_loss: 3.2262e-05 - val_Scalars_Output_loss: 3.5595e-04 - val_Thrust_Output_loss: 9.9319e-06 - val_loss: 3.7722e-04 - learning_rate: 1.0000e-05
# Epoch 372/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8483e-05 - Scalars_Output_loss: 3.5197e-04 - Thrust_Output_loss: 5.8587e-06 - loss: 3.7614e-04 - val_Pressure_Output_loss: 2.9925e-05 - val_Scalars_Output_loss: 3.6132e-04 - val_Thrust_Output_loss: 9.1433e-06 - val_loss: 3.7840e-04 - learning_rate: 1.0000e-05
# Epoch 373/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.8941e-05 - Scalars_Output_loss: 3.3277e-04 - Thrust_Output_loss: 5.9837e-06 - loss: 3.5777e-04 - val_Pressure_Output_loss: 3.0937e-05 - val_Scalars_Output_loss: 3.5804e-04 - val_Thrust_Output_loss: 9.9344e-06 - val_loss: 3.7870e-04 - learning_rate: 1.0000e-05
# Epoch 374/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7844e-05 - Scalars_Output_loss: 3.4388e-04 - Thrust_Output_loss: 5.9334e-06 - loss: 3.6749e-04 - val_Pressure_Output_loss: 3.0813e-05 - val_Scalars_Output_loss: 3.5597e-04 - val_Thrust_Output_loss: 9.4399e-06 - val_loss: 3.7499e-04 - learning_rate: 1.0000e-05
# Epoch 375/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.8422e-05 - Scalars_Output_loss: 3.4768e-04 - Thrust_Output_loss: 5.7393e-06 - loss: 3.7176e-04 - val_Pressure_Output_loss: 3.0182e-05 - val_Scalars_Output_loss: 3.5504e-04 - val_Thrust_Output_loss: 9.7398e-06 - val_loss: 3.7385e-04 - learning_rate: 1.0000e-05
# Epoch 376/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8433e-05 - Scalars_Output_loss: 3.5512e-04 - Thrust_Output_loss: 5.7312e-06 - loss: 3.7934e-04 - val_Pressure_Output_loss: 2.8921e-05 - val_Scalars_Output_loss: 3.5545e-04 - val_Thrust_Output_loss: 9.1798e-06 - val_loss: 3.7198e-04 - learning_rate: 1.0000e-05
# Epoch 377/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7342e-05 - Scalars_Output_loss: 3.6376e-04 - Thrust_Output_loss: 5.6246e-06 - loss: 3.8681e-04 - val_Pressure_Output_loss: 2.9689e-05 - val_Scalars_Output_loss: 3.5878e-04 - val_Thrust_Output_loss: 9.2739e-06 - val_loss: 3.7591e-04 - learning_rate: 1.0000e-05
# Epoch 378/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8088e-05 - Scalars_Output_loss: 3.2375e-04 - Thrust_Output_loss: 5.6033e-06 - loss: 3.4752e-04 - val_Pressure_Output_loss: 2.9840e-05 - val_Scalars_Output_loss: 3.5656e-04 - val_Thrust_Output_loss: 9.4130e-06 - val_loss: 3.7488e-04 - learning_rate: 1.0000e-05
# Epoch 379/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7841e-05 - Scalars_Output_loss: 3.2583e-04 - Thrust_Output_loss: 6.1328e-06 - loss: 3.4983e-04 - val_Pressure_Output_loss: 3.3575e-05 - val_Scalars_Output_loss: 3.5429e-04 - val_Thrust_Output_loss: 1.1267e-05 - val_loss: 3.7908e-04 - learning_rate: 1.0000e-05
# Epoch 380/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.9785e-05 - Scalars_Output_loss: 3.3788e-04 - Thrust_Output_loss: 6.4342e-06 - loss: 3.6421e-04 - val_Pressure_Output_loss: 2.8803e-05 - val_Scalars_Output_loss: 3.5758e-04 - val_Thrust_Output_loss: 8.7849e-06 - val_loss: 3.7378e-04 - learning_rate: 1.0000e-05
# Epoch 381/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7362e-05 - Scalars_Output_loss: 3.3828e-04 - Thrust_Output_loss: 5.8208e-06 - loss: 3.6145e-04 - val_Pressure_Output_loss: 2.9516e-05 - val_Scalars_Output_loss: 3.5403e-04 - val_Thrust_Output_loss: 1.0615e-05 - val_loss: 3.7378e-04 - learning_rate: 1.0000e-05
# Epoch 382/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.9054e-05 - Scalars_Output_loss: 3.2143e-04 - Thrust_Output_loss: 6.5698e-06 - loss: 3.4715e-04 - val_Pressure_Output_loss: 2.9002e-05 - val_Scalars_Output_loss: 3.5717e-04 - val_Thrust_Output_loss: 9.1975e-06 - val_loss: 3.7330e-04 - learning_rate: 1.0000e-05
# Epoch 383/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7442e-05 - Scalars_Output_loss: 3.4151e-04 - Thrust_Output_loss: 6.2855e-06 - loss: 3.6498e-04 - val_Pressure_Output_loss: 3.0881e-05 - val_Scalars_Output_loss: 3.5631e-04 - val_Thrust_Output_loss: 9.1428e-06 - val_loss: 3.7526e-04 - learning_rate: 1.0000e-05
# Epoch 384/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.6897e-05 - Scalars_Output_loss: 3.0842e-04 - Thrust_Output_loss: 5.5999e-06 - loss: 3.3087e-04 - val_Pressure_Output_loss: 3.1433e-05 - val_Scalars_Output_loss: 3.5640e-04 - val_Thrust_Output_loss: 9.8607e-06 - val_loss: 3.7704e-04 - learning_rate: 1.0000e-05
# Epoch 385/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.8036e-05 - Scalars_Output_loss: 3.5134e-04 - Thrust_Output_loss: 5.8403e-06 - loss: 3.7528e-04 - val_Pressure_Output_loss: 3.0028e-05 - val_Scalars_Output_loss: 3.5464e-04 - val_Thrust_Output_loss: 9.8023e-06 - val_loss: 3.7364e-04 - learning_rate: 1.0000e-05
# Epoch 386/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7220e-05 - Scalars_Output_loss: 3.5357e-04 - Thrust_Output_loss: 5.5196e-06 - loss: 3.7616e-04 - val_Pressure_Output_loss: 3.5266e-05 - val_Scalars_Output_loss: 3.5511e-04 - val_Thrust_Output_loss: 9.9550e-06 - val_loss: 3.7916e-04 - learning_rate: 1.0000e-05
# Epoch 387/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8123e-05 - Scalars_Output_loss: 3.4833e-04 - Thrust_Output_loss: 5.5999e-06 - loss: 3.7199e-04 - val_Pressure_Output_loss: 3.0837e-05 - val_Scalars_Output_loss: 3.5562e-04 - val_Thrust_Output_loss: 9.9104e-06 - val_loss: 3.7343e-04 - learning_rate: 1.0000e-05
# Epoch 388/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.8721e-05 - Scalars_Output_loss: 3.2535e-04 - Thrust_Output_loss: 7.0364e-06 - loss: 3.5088e-04 - val_Pressure_Output_loss: 2.8796e-05 - val_Scalars_Output_loss: 3.5104e-04 - val_Thrust_Output_loss: 9.6217e-06 - val_loss: 3.6832e-04 - learning_rate: 1.0000e-05
# Epoch 389/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.9080e-05 - Scalars_Output_loss: 3.3399e-04 - Thrust_Output_loss: 6.1119e-06 - loss: 3.5925e-04 - val_Pressure_Output_loss: 3.0566e-05 - val_Scalars_Output_loss: 3.5148e-04 - val_Thrust_Output_loss: 9.0589e-06 - val_loss: 3.7045e-04 - learning_rate: 1.0000e-05
# Epoch 390/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7958e-05 - Scalars_Output_loss: 3.2668e-04 - Thrust_Output_loss: 5.6658e-06 - loss: 3.5039e-04 - val_Pressure_Output_loss: 3.0083e-05 - val_Scalars_Output_loss: 3.5171e-04 - val_Thrust_Output_loss: 9.4933e-06 - val_loss: 3.7076e-04 - learning_rate: 1.0000e-05
# Epoch 391/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.6631e-05 - Scalars_Output_loss: 3.3834e-04 - Thrust_Output_loss: 5.4531e-06 - loss: 3.6025e-04 - val_Pressure_Output_loss: 2.8381e-05 - val_Scalars_Output_loss: 3.5918e-04 - val_Thrust_Output_loss: 9.0366e-06 - val_loss: 3.7617e-04 - learning_rate: 1.0000e-05
# Epoch 392/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.7369e-05 - Scalars_Output_loss: 3.1444e-04 - Thrust_Output_loss: 5.6551e-06 - loss: 3.3752e-04 - val_Pressure_Output_loss: 2.8530e-05 - val_Scalars_Output_loss: 3.5765e-04 - val_Thrust_Output_loss: 9.1302e-06 - val_loss: 3.7312e-04 - learning_rate: 1.0000e-05
# Epoch 393/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.9066e-05 - Scalars_Output_loss: 3.6682e-04 - Thrust_Output_loss: 6.5715e-06 - loss: 3.9250e-04 - val_Pressure_Output_loss: 3.1375e-05 - val_Scalars_Output_loss: 3.5526e-04 - val_Thrust_Output_loss: 1.0143e-05 - val_loss: 3.7488e-04 - learning_rate: 1.0000e-05
# Epoch 394/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7120e-05 - Scalars_Output_loss: 3.4208e-04 - Thrust_Output_loss: 5.5941e-06 - loss: 3.6488e-04 - val_Pressure_Output_loss: 2.7945e-05 - val_Scalars_Output_loss: 3.5255e-04 - val_Thrust_Output_loss: 8.6916e-06 - val_loss: 3.6893e-04 - learning_rate: 1.0000e-05
# Epoch 395/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.6501e-05 - Scalars_Output_loss: 3.1973e-04 - Thrust_Output_loss: 5.4171e-06 - loss: 3.4113e-04 - val_Pressure_Output_loss: 2.9240e-05 - val_Scalars_Output_loss: 3.5246e-04 - val_Thrust_Output_loss: 9.8362e-06 - val_loss: 3.7049e-04 - learning_rate: 1.0000e-05
# Epoch 396/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 2.1899e-05 - Scalars_Output_loss: 3.5952e-04 - Thrust_Output_loss: 7.6677e-06 - loss: 3.8916e-04 - val_Pressure_Output_loss: 2.9662e-05 - val_Scalars_Output_loss: 3.5202e-04 - val_Thrust_Output_loss: 9.5560e-06 - val_loss: 3.7075e-04 - learning_rate: 1.0000e-05
# Epoch 397/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.6891e-05 - Scalars_Output_loss: 3.1940e-04 - Thrust_Output_loss: 5.5392e-06 - loss: 3.4179e-04 - val_Pressure_Output_loss: 2.9215e-05 - val_Scalars_Output_loss: 3.5375e-04 - val_Thrust_Output_loss: 9.6841e-06 - val_loss: 3.7253e-04 - learning_rate: 1.0000e-05
# Epoch 398/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - Pressure_Output_loss: 1.8111e-05 - Scalars_Output_loss: 3.0423e-04 - Thrust_Output_loss: 5.8592e-06 - loss: 3.2804e-04 - val_Pressure_Output_loss: 2.8737e-05 - val_Scalars_Output_loss: 3.5646e-04 - val_Thrust_Output_loss: 8.7223e-06 - val_loss: 3.7314e-04 - learning_rate: 1.0000e-05
# Epoch 399/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.9802e-05 - Scalars_Output_loss: 3.4532e-04 - Thrust_Output_loss: 6.5928e-06 - loss: 3.7171e-04 - val_Pressure_Output_loss: 2.9551e-05 - val_Scalars_Output_loss: 3.6098e-04 - val_Thrust_Output_loss: 9.3383e-06 - val_loss: 3.7902e-04 - learning_rate: 1.0000e-05
# Epoch 400/400
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - Pressure_Output_loss: 1.7052e-05 - Scalars_Output_loss: 3.1691e-04 - Thrust_Output_loss: 5.2118e-06 - loss: 3.3923e-04 - val_Pressure_Output_loss: 2.8282e-05 - val_Scalars_Output_loss: 3.5260e-04 - val_Thrust_Output_loss: 8.4684e-06 - val_loss: 3.6801e-04 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 400.

# %%
# حفظ الموديل
moon_forward.save('Conical_Forward_Model.keras')
print("\n✅ Conical Forward Model trained and saved successfully.")
# Out:
# ✅ Conical Forward Model trained and saved successfully.

# %%
# رسم منحنى التعلّم الكلي
plt.figure(figsize=(8, 4))
plt.plot(history_fwd.history['loss'], label='Train Total Loss')
plt.plot(history_fwd.history['val_loss'], label='Val Total Loss')
plt.title('Conical Forward Model - Training History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# ===================================================================
# 6. Training Curves for Moon Forward Model
# ===================================================================
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
best_ep = np.argmin(history_fwd.history['val_loss'])

# 1. Total Loss
ax = axes[0, 0]
ax.plot(history_fwd.history['loss'],     label='Train', linewidth=2)
ax.plot(history_fwd.history['val_loss'], label='Val',   linewidth=2, linestyle='--')
ax.axvline(best_ep, color='red', linestyle=':', label=f'Best ({best_ep})')
ax.set_title('Total Loss'); ax.set_xlabel('Epochs')
ax.legend(); ax.grid(True, alpha=0.3)

# 2. Thrust Loss
ax = axes[0, 1]
ax.plot(history_fwd.history['Thrust_Output_loss'],     label='Train', color='blue',    linewidth=2)
ax.plot(history_fwd.history['val_Thrust_Output_loss'], label='Val',   color='cyan', linewidth=2, linestyle='--')
ax.set_title('Thrust Loss (Huber)'); ax.set_xlabel('Epochs')
ax.legend(); ax.grid(True, alpha=0.3)

# 3. Pressure Loss
ax = axes[0, 2]
ax.plot(history_fwd.history['Pressure_Output_loss'],     label='Train', color='green', linewidth=2)
ax.plot(history_fwd.history['val_Pressure_Output_loss'], label='Val',   color='lightgreen', linewidth=2, linestyle='--')
ax.set_title('Pressure Loss (Huber)'); ax.set_xlabel('Epochs')
ax.legend(); ax.grid(True, alpha=0.3)

# 4. Scalars Loss (ISP, Impulse, BurnTime, MaxThrust)
ax = axes[1, 0]
ax.plot(history_fwd.history['Scalars_Output_loss'],     label='Train', color='purple', linewidth=2)
ax.plot(history_fwd.history['val_Scalars_Output_loss'], label='Val',   color='violet', linewidth=2, linestyle='--')
ax.set_title('Scalars Loss (MAE)'); ax.set_xlabel('Epochs')
ax.legend(); ax.grid(True, alpha=0.3)

# 5. Overfitting Gap
ax = axes[1, 1]
gap = np.array(history_fwd.history['val_loss']) - np.array(history_fwd.history['loss'])
ax.plot(gap, color='purple', linewidth=2)
ax.axhline(0, color='black', linestyle='--')
ax.fill_between(range(len(gap)), gap, 0,
                where=(gap > 0), alpha=0.3, color='red',   label='Overfit')
ax.fill_between(range(len(gap)), gap, 0,
                where=(gap < 0), alpha=0.3, color='green', label='Healthy')
ax.set_title('Overfitting Gap')
ax.legend(); ax.grid(True, alpha=0.3)

# 6. Learning Rate Decay (متابعة تناقص معدل التعلم)
ax = axes[1, 2]
if 'learning_rate' in history_fwd.history:
    ax.plot(history_fwd.history['learning_rate'], color='orange', linewidth=2)
    ax.set_title('Learning Rate Decay')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('LR')
    ax.grid(True, alpha=0.3)
else:
    ax.axis('off') # إخفاء المربع إذا لم يكن معدل التعلم متاحاً

plt.tight_layout()
plt.show()

# %%
# ===================================================================
# 7. Prediction Function for Moon Forward Model (Clean Curve)
# ===================================================================
def get_user_input_and_predict_conical():
    print('\n' + '='*55)
    print('   Moon Grain - Performance Predictor (ReLU Edition)')
    print('='*55)
    try:
        l_val  = float(input('Length (cm):               '))
        od_val = float(input('Diameter (cm):       '))
        id_val = float(input('Forward_Core_Diameter (cm):  '))
        co_val = float(input('Aft_Core_Diameter (cm):          ')) 
        td_val = float(input('Throat Diameter (cm):      '))
        ed_val = float(input('Exit Diameter (cm):        '))

        user_inputs        = np.array([[l_val, od_val, id_val, co_val, td_val, ed_val]])
        user_inputs_scaled = s_X.transform(user_inputs)

        preds = moon_forward.predict(user_inputs_scaled, verbose=0)

        max_vals = joblib.load('con_fwd_max_values.pkl')
        yt_max = max_vals['yt_max']
        yp_max = max_vals['yp_max']

        # استخراج المنحنيات
        thrust_pred   = preds[0][0] * yt_max
        pressure_pred = preds[1][0] * yp_max
        
        # استخراج القيم الثابتة
        scalars_pred  = s_ys.inverse_transform(preds[2])[0]
        isp           = max(scalars_pred[0], 1e-9)
        burn_time     = max(scalars_pred[2], 1e-9)
        max_thrust_sc = max(scalars_pred[3], 1e-9)

        time_steps = np.linspace(0, burn_time, 100)

        # تنعيم خفيف للمنحنى بدون التأثير على القمة
        smoothed_thrust   = np.clip(savgol_filter(thrust_pred, window_length=7, polyorder=2), 0, None)
        smoothed_pressure = np.clip(savgol_filter(pressure_pred, window_length=7, polyorder=2), 0, None)

        # إغلاق ذيل المنحنى
        peak_idx = np.argmax(smoothed_thrust)
        tail     = smoothed_thrust[peak_idx:]
        cutoff   = np.argmax(tail < 0.02 * smoothed_thrust.max())
        if cutoff > 0:
            smoothed_thrust[peak_idx + cutoff:] = 0
            smoothed_pressure[peak_idx + cutoff:] = 0

        # حساب المساحة من المنحنى النهائي
        calculated_impulse = np.trapezoid(smoothed_thrust, time_steps)
        final_max_thrust = np.max(smoothed_thrust)

        print('\n' + '-'*45)
        print('   Predicted Performance (Conical Grain)')
        print('-'*45)
        print(f'  ISP                   : {isp:.2f} s')
        print(f'  Burn Time             : {burn_time:.2f} s')
        print(f'  Total Impulse         : {calculated_impulse:.2f} N.s')
        print(f'  Max Thrust            : {final_max_thrust:.2f} N')
        print('-'*45)

        fig, axes = plt.subplots(1, 2, figsize=(15, 5))

        axes[0].plot(time_steps, smoothed_thrust, color='red', linewidth=2)
        axes[0].set_title('Predicted Thrust Curve')
        axes[0].set_xlabel('Time (s)'); axes[0].set_ylabel('Thrust (N)')
        axes[0].grid(True, alpha=0.3)

        axes[1].plot(time_steps, smoothed_pressure, color='blue', linewidth=2)
        axes[1].set_title('Predicted Pressure Curve')
        axes[1].set_xlabel('Time (s)'); axes[1].set_ylabel('Pressure (MPa)')
        axes[1].grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()

    except ValueError:
        print('\n[Error]: Please enter valid numeric values.')
    except Exception as e:
        print(f'\n[Error]: {e}')

get_user_input_and_predict_conical()
# Out:
# =======================================================
#    Moon Grain - Performance Predictor (ReLU Edition)
# =======================================================
# Length (cm):                130
# Diameter (cm):        8
# Forward_Core_Diameter (cm):   3
# Aft_Core_Diameter (cm):           4.5
# Throat Diameter (cm):       2.9
# Exit Diameter (cm):         4.35
# ---------------------------------------------
#    Predicted Performance (Conical Grain)
# ---------------------------------------------
#   ISP                   : 171.47 s
#   Burn Time             : 5.10 s
#   Total Impulse         : 15637.95 N.s
#   Max Thrust            : 6473.15 N
# ---------------------------------------------
